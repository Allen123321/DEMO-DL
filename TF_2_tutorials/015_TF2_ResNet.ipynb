# %% [markdown]
# <a href="https://colab.research.google.com/github/Allen123321/DEMO-DL/blob/master/015_TF2_ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras.models import Model
import numpy as np
import os
import tensorflow as tf

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
# Convert class vectors to binary class matrices.
train_labels = tf.keras.utils.to_categorical(train_labels, 10)
test_labels = tf.keras.utils.to_categorical(test_labels, 10)

# %%
# Training parameters
batch_size = 32
epochs = 100
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
depth = n * 6 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Input image dimensions.
input_shape = train_images.shape[1:]

# Normalize data.
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

# %%
# If subtract pixel mean is enabled
if subtract_pixel_mean:
    train_images_mean = np.mean(train_images, axis=0)
    train_images -= train_images_mean
    test_images -= train_images_mean

# %%
print('train_images shape:', train_images.shape)
print(train_images.shape[0], 'train samples')
print(test_images.shape[0], 'test samples')
print('train labels shape:', train_labels.shape)
# Out:
# train_images shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# train labels shape: (50000, 10)

# %%
# Learning Rate Schedule
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
# resnet layer
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):

    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    # ResNet Version 1 Model builder [a]
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v1(input_shape=input_shape, depth=depth, num_classes=num_classes)
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 16)   0           activation[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 16)   0           activation_4[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 32)   4640        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   544         activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 32)   0           conv2d_9[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 32)   0           activation_8[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 32)   0           activation_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 64)     18496       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 64)     256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 64)     0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     36928       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 64)     2112        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 64)     0           conv2d_16[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 64)     0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 64)     256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 64)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 64)     256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 64)     0           activation_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 64)     0           activation_16[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 64)     0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 64)           0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           650         flatten[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'garbage_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Run training, with or without data augmentation.
# print('Using real-time data augmentation.')
# This will do preprocessing and realtime data augmentation:

datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

# %%
datagen.fit(train_images)

# %%
# Fit the model on the batches generated by datagen.flow().
model.fit_generator(datagen.flow(train_images, train_labels, batch_size=batch_size),
                    steps_per_epoch=len(train_images) // batch_size,
                    validation_data=(test_images, test_labels),
                    epochs=epochs, verbose=1, workers=4,
                    callbacks=callbacks)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 54s 32ms/step - loss: 1.8993 - accuracy: 0.3919 - val_loss: 1.8685 - val_accuracy: 0.4451
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 1.2257 - accuracy: 0.6203 - val_loss: 1.0584 - val_accuracy: 0.6870
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 1.0430 - accuracy: 0.6872 - val_loss: 1.1114 - val_accuracy: 0.6864
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.9530 - accuracy: 0.7280 - val_loss: 0.9665 - val_accuracy: 0.7276
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.8723 - accuracy: 0.7525 - val_loss: 1.1134 - val_accuracy: 0.6966
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.8265 - accuracy: 0.7700 - val_loss: 1.2258 - val_accuracy: 0.6655
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.7820 - accuracy: 0.7878 - val_loss: 1.0394 - val_accuracy: 0.7195
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.7564 - accuracy: 0.7991 - val_loss: 0.9579 - val_accuracy: 0.7420
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.7347 - accuracy: 0.8062 - val_loss: 0.8324 - val_accuracy: 0.7839
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.7160 - accuracy: 0.8142 - val_loss: 0.9890 - val_accuracy: 0.7460
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.6942 - accuracy: 0.8233 - val_loss: 0.9919 - val_accuracy: 0.7261
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.6761 - accuracy: 0.8285 - val_loss: 0.8196 - val_accuracy: 0.7868
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.6655 - accuracy: 0.8337 - val_loss: 0.8076 - val_accuracy: 0.7976
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.6577 - accuracy: 0.8368 - val_loss: 0.7967 - val_accuracy: 0.7981
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.6506 - accuracy: 0.8393 - val_loss: 0.7903 - val_accuracy: 0.7934
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.6278 - accuracy: 0.8507 - val_loss: 0.9015 - val_accuracy: 0.7748
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.6186 - accuracy: 0.8525 - val_loss: 0.8098 - val_accuracy: 0.7997
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.6077 - accuracy: 0.8548 - val_loss: 1.0021 - val_accuracy: 0.7573
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.6055 - accuracy: 0.8590 - val_loss: 0.7787 - val_accuracy: 0.8027
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.6039 - accuracy: 0.8583 - val_loss: 0.7279 - val_accuracy: 0.8228
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.6008 - accuracy: 0.8608 - val_loss: 0.6720 - val_accuracy: 0.8384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5837 - accuracy: 0.8655 - val_loss: 1.1976 - val_accuracy: 0.7319
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5842 - accuracy: 0.8648 - val_loss: 0.6605 - val_accuracy: 0.8451
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5765 - accuracy: 0.8689 - val_loss: 0.7259 - val_accuracy: 0.8247
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5770 - accuracy: 0.8679 - val_loss: 0.6540 - val_accuracy: 0.8432
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5674 - accuracy: 0.8731 - val_loss: 0.8469 - val_accuracy: 0.7961
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5642 - accuracy: 0.8749 - val_loss: 0.7041 - val_accuracy: 0.8358
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.5583 - accuracy: 0.8753 - val_loss: 0.6588 - val_accuracy: 0.8466
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5492 - accuracy: 0.8802 - val_loss: 0.9011 - val_accuracy: 0.7901
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5559 - accuracy: 0.8758 - val_loss: 0.7826 - val_accuracy: 0.8111
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5540 - accuracy: 0.8786 - val_loss: 0.6765 - val_accuracy: 0.8390
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5538 - accuracy: 0.8783 - val_loss: 0.7049 - val_accuracy: 0.8325
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5556 - accuracy: 0.8780 - val_loss: 0.7354 - val_accuracy: 0.8269
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5398 - accuracy: 0.8845 - val_loss: 0.6838 - val_accuracy: 0.8492
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5390 - accuracy: 0.8836 - val_loss: 0.6971 - val_accuracy: 0.8319
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.5369 - accuracy: 0.8833 - val_loss: 0.7382 - val_accuracy: 0.8257
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5316 - accuracy: 0.8861 - val_loss: 0.8454 - val_accuracy: 0.8047
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5372 - accuracy: 0.8844 - val_loss: 0.6336 - val_accuracy: 0.8598
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.5337 - accuracy: 0.8874 - val_loss: 0.8566 - val_accuracy: 0.8036
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5267 - accuracy: 0.8887 - val_loss: 0.8638 - val_accuracy: 0.8053
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5271 - accuracy: 0.8896 - val_loss: 0.7298 - val_accuracy: 0.8316
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5204 - accuracy: 0.8893 - val_loss: 0.7990 - val_accuracy: 0.8077
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5257 - accuracy: 0.8888 - val_loss: 0.7428 - val_accuracy: 0.8184
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5216 - accuracy: 0.8919 - val_loss: 0.9447 - val_accuracy: 0.7763
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5239 - accuracy: 0.8890 - val_loss: 0.6778 - val_accuracy: 0.8467
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5230 - accuracy: 0.8911 - val_loss: 0.8460 - val_accuracy: 0.8033
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.5244 - accuracy: 0.8900 - val_loss: 0.6650 - val_accuracy: 0.8532
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.5162 - accuracy: 0.8917 - val_loss: 0.6620 - val_accuracy: 0.8502
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5148 - accuracy: 0.8940 - val_loss: 0.7630 - val_accuracy: 0.8235
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 50/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5150 - accuracy: 0.8908 - val_loss: 0.9206 - val_accuracy: 0.7837
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 51/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5093 - accuracy: 0.8947 - val_loss: 0.7014 - val_accuracy: 0.8384
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 52/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5165 - accuracy: 0.8922 - val_loss: 0.7185 - val_accuracy: 0.8391
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 53/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5036 - accuracy: 0.8971 - val_loss: 0.8073 - val_accuracy: 0.8152
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 54/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5125 - accuracy: 0.8932 - val_loss: 0.6366 - val_accuracy: 0.8566
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 55/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.5047 - accuracy: 0.8982 - val_loss: 0.7031 - val_accuracy: 0.8422
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 56/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5049 - accuracy: 0.8967 - val_loss: 0.7377 - val_accuracy: 0.8392
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 57/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5051 - accuracy: 0.8962 - val_loss: 0.8553 - val_accuracy: 0.8047
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 58/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5021 - accuracy: 0.8960 - val_loss: 0.6492 - val_accuracy: 0.8558
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 59/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5100 - accuracy: 0.8940 - val_loss: 0.7050 - val_accuracy: 0.8372
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 60/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5060 - accuracy: 0.8948 - val_loss: 0.6944 - val_accuracy: 0.8466
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 61/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4994 - accuracy: 0.8996 - val_loss: 0.6783 - val_accuracy: 0.8492
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 62/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.4918 - accuracy: 0.9005 - val_loss: 0.7635 - val_accuracy: 0.8198
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 63/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5032 - accuracy: 0.8978 - val_loss: 0.6715 - val_accuracy: 0.8523
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 64/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.5026 - accuracy: 0.8978 - val_loss: 0.7949 - val_accuracy: 0.8181
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 65/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.4957 - accuracy: 0.8992 - val_loss: 0.7958 - val_accuracy: 0.8218
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 66/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.4982 - accuracy: 0.9004 - val_loss: 0.6458 - val_accuracy: 0.8499
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 67/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 48s 31ms/step - loss: 0.4875 - accuracy: 0.8998 - val_loss: 0.6588 - val_accuracy: 0.8542
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 68/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4988 - accuracy: 0.8987 - val_loss: 0.7252 - val_accuracy: 0.8402
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 69/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4905 - accuracy: 0.9009 - val_loss: 0.6732 - val_accuracy: 0.8508
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 70/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4969 - accuracy: 0.8983 - val_loss: 0.6576 - val_accuracy: 0.8504
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 71/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4982 - accuracy: 0.8986 - val_loss: 0.7914 - val_accuracy: 0.8227
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 72/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4897 - accuracy: 0.9018 - val_loss: 0.7141 - val_accuracy: 0.8345
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 73/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4905 - accuracy: 0.9018 - val_loss: 0.7532 - val_accuracy: 0.8311
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 74/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.4926 - accuracy: 0.9005 - val_loss: 0.6628 - val_accuracy: 0.8517
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 75/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.4876 - accuracy: 0.9001 - val_loss: 0.7510 - val_accuracy: 0.8404
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 76/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4898 - accuracy: 0.9020 - val_loss: 0.6868 - val_accuracy: 0.8498
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 77/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4832 - accuracy: 0.9051 - val_loss: 0.7221 - val_accuracy: 0.8387
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 78/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4886 - accuracy: 0.9033 - val_loss: 0.8142 - val_accuracy: 0.8143
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 79/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4772 - accuracy: 0.9059 - val_loss: 0.6096 - val_accuracy: 0.8664
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 80/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.4859 - accuracy: 0.9033 - val_loss: 0.6547 - val_accuracy: 0.8535
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 81/100
# Learning rate:  0.001
# 1562/1562 [==============================] - 49s 31ms/step - loss: 0.4825 - accuracy: 0.9036 - val_loss: 0.6896 - val_accuracy: 0.8488
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 82/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.4244 - accuracy: 0.9257 - val_loss: 0.5041 - val_accuracy: 0.9007
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 83/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.3797 - accuracy: 0.9389 - val_loss: 0.4826 - val_accuracy: 0.9071
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 84/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.3598 - accuracy: 0.9434 - val_loss: 0.4816 - val_accuracy: 0.9080
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 85/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.3471 - accuracy: 0.9473 - val_loss: 0.4710 - val_accuracy: 0.9105
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 86/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.3342 - accuracy: 0.9513 - val_loss: 0.4741 - val_accuracy: 0.9075
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 87/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.3338 - accuracy: 0.9514 - val_loss: 0.4691 - val_accuracy: 0.9109
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 88/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.3199 - accuracy: 0.9543 - val_loss: 0.4700 - val_accuracy: 0.9065
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 89/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.3113 - accuracy: 0.9567 - val_loss: 0.4606 - val_accuracy: 0.9111
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 90/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.3024 - accuracy: 0.9576 - val_loss: 0.4679 - val_accuracy: 0.9090
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 91/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.3041 - accuracy: 0.9569 - val_loss: 0.4580 - val_accuracy: 0.9130
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 92/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.2934 - accuracy: 0.9592 - val_loss: 0.4519 - val_accuracy: 0.9118
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 93/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.2925 - accuracy: 0.9583 - val_loss: 0.4590 - val_accuracy: 0.9110
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 94/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.2887 - accuracy: 0.9584 - val_loss: 0.4551 - val_accuracy: 0.9116
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 95/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.2802 - accuracy: 0.9609 - val_loss: 0.4554 - val_accuracy: 0.9102
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 96/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.2733 - accuracy: 0.9627 - val_loss: 0.4501 - val_accuracy: 0.9113
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 97/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.2732 - accuracy: 0.9612 - val_loss: 0.4581 - val_accuracy: 0.9080
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 98/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.2662 - accuracy: 0.9641 - val_loss: 0.4567 - val_accuracy: 0.9090
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 99/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 50s 32ms/step - loss: 0.2618 - accuracy: 0.9654 - val_loss: 0.4569 - val_accuracy: 0.9116
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 100/100
# Learning rate:  0.0001
# 1562/1562 [==============================] - 49s 32ms/step - loss: 0.2578 - accuracy: 0.9654 - val_loss: 0.4514 - val_accuracy: 0.9117
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.

# %%
# Score trained model.
scores = model.evaluate(test_images, test_labels, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4514 - accuracy: 0.9117
# Test loss: 0.4514352083206177
# Test accuracy: 0.9117000102996826

# %%
import tensorflow as tf

class BasicBlock(tf.keras.Model):
  expansion = 1

  def __init__(self, in_channels, out_channels, strides=1):
      super(BasicBlock, self).__init__()
      self.conv1 = tf.keras.layers.Conv2D(out_channels, kernel_size=3, strides=strides,
                                          padding="same", use_bias=False)
      self.bn1 = tf.keras.layers.BatchNormalization()

      self.conv2 = tf.keras.layers.Conv2D(out_channels, kernel_size=3, strides=1,
                                          padding="same", use_bias=False)
      self.bn2 = tf.keras.layers.BatchNormalization()

      """
      Adds a shortcut between input and residual block and merges them with "sum"
      """
      if strides != 1 or in_channels != self.expansion * out_channels:
          self.shortcut = tf.keras.Sequential([
                  tf.keras.layers.Conv2D(self.expansion*out_channels, kernel_size=1,
                                          strides=strides, use_bias=False),
                  tf.keras.layers.BatchNormalization()]
                  )
      else:
          self.shortcut = lambda x,_: x

  def call(self, x, training=False):
      # if training: print("=> training network ... ")
      out = tf.nn.relu(self.bn1(self.conv1(x), training=training))
      out = self.bn2(self.conv2(out), training=training)
      out += self.shortcut(x, training)
      return tf.nn.relu(out)

# %%
class Bottleneck(tf.keras.Model):
    expansion = 4

    def __init__(self, in_channels, out_channels, strides=1):
        super(Bottleneck, self).__init__()

        self.conv1 = tf.keras.layers.Conv2D(out_channels, 1, 1, use_bias=False)
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.conv2 = tf.keras.layers.Conv2D(out_channels, 3, strides, padding="same", use_bias=False)
        self.bn2 = tf.keras.layers.BatchNormalization()
        self.conv3 = tf.keras.layers.Conv2D(out_channels*self.expansion, 1, 1, use_bias=False)
        self.bn3 = tf.keras.layers.BatchNormalization()

        if strides != 1 or in_channels != self.expansion * out_channels:
            self.shortcut = tf.keras.Sequential([
                    tf.keras.layers.Conv2D(self.expansion*out_channels, kernel_size=1,
                                           strides=strides, use_bias=False),
                    tf.keras.layers.BatchNormalization()]
                    )
        else:
            self.shortcut = lambda x,_: x

    def call(self, x, training=False):
        out = tf.nn.relu(self.bn1(self.conv1(x), training))
        out = tf.nn.relu(self.bn2(self.conv2(out), training))
        out = self.bn3(self.conv3(out), training)
        out += self.shortcut(x, training)
        return tf.nn.relu(out)


class ResNet(tf.keras.Model):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_channels = 64

        self.conv1 = tf.keras.layers.Conv2D(64, 3, 1, padding="same", use_bias=False)
        self.bn1 = tf.keras.layers.BatchNormalization()

        self.layer1 = self._make_layer(block,  64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)

        self.avg_pool2d = tf.keras.layers.AveragePooling2D(4)
        self.linear = tf.keras.layers.Dense(units=num_classes, activation="softmax")

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels * block.expansion
        return tf.keras.Sequential(layers)

    def call(self, x, training=False):
        out = tf.nn.relu(self.bn1(self.conv1(x), training))
        out = self.layer1(out, training=training)
        out = self.layer2(out, training=training)
        out = self.layer3(out, training=training)
        out = self.layer4(out, training=training)

        # For classification
        out = self.avg_pool2d(out)
        out = tf.reshape(out, (out.shape[0], -1))
        out = self.linear(out)
        return out

def ResNet18():
    return ResNet(BasicBlock, [2,2,2,2])

def ResNet34():
    return ResNet(BasicBlock, [3,4,6,3])

def ResNet50():
    return ResNet(Bottleneck, [3,4,14,3])

def ResNet101():
    return ResNet(Bottleneck, [3,4,23,3])

def ResNet152():
    return ResNet(Bottleneck, [3,8,36,3])
