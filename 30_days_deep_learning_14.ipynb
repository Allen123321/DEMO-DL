# %% [markdown]
# <a href="https://colab.research.google.com/github/Allen123321/DEMO-DL/blob/master/30_days_deep_learning_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 5-1,数据管道Dataset
# 如果需要训练的数据大小不大，例如不到1G，那么可以直接全部读入内存中进行训练，这样一般效率最高。
#
# 但如果需要训练的数据很大，例如超过10G，无法一次载入内存，那么通常需要在训练的过程中分批逐渐读入。
#
# 使用 tf.data API 可以构建数据输入管道，轻松处理大量的数据，不同的数据格式，以及不同的数据转换。
# ### 一，构建数据管道
# 可以从 Numpy array, Pandas DataFrame, Python generator, csv文件, 文本文件, 文件路径, tfrecords文件等方式构建数据管道。
#
# 其中通过Numpy array, Pandas DataFrame, 文件路径构建数据管道是最常用的方法。
#
# 通过tfrecords文件方式构建数据管道较为复杂，需要对样本构建tf.Example后压缩成字符串写到tfrecords文件，读取后再解析成tf.Example。
#
# 但tfrecords文件的优点是压缩后文件较小，便于网络传播，加载速度较快。
# ### 1,从Numpy array构建数据管道

# %%
# 从Numpy array构建数据管道
import tensorflow as tf
import numpy as np
from sklearn import datasets
iris = datasets.load_iris()

# %%
ds1 = tf.data.Dataset.from_tensor_slices((iris["data"],iris["target"]))
for features,label in ds1.take(5):
  print(features,label)
# Out:
# tf.Tensor([5.1 3.5 1.4 0.2], shape=(4,), dtype=float64) tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor([4.9 3.  1.4 0.2], shape=(4,), dtype=float64) tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor([4.7 3.2 1.3 0.2], shape=(4,), dtype=float64) tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor([4.6 3.1 1.5 0.2], shape=(4,), dtype=float64) tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor([5.  3.6 1.4 0.2], shape=(4,), dtype=float64) tf.Tensor(0, shape=(), dtype=int64)

# %%
# 2,从 Pandas DataFrame构建数据管道
# 从 Pandas DataFrame构建数据管道
import tensorflow as tf
from sklearn import datasets 
import pandas as pd
iris = datasets.load_iris()
dfiris = pd.DataFrame(iris["data"],columns = iris.feature_names)
ds2 = tf.data.Dataset.from_tensor_slices((dfiris.to_dict("list"),iris["target"]))

for features,label in ds2.take(3):
  print(features,label)
# Out:
# {'sepal length (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=5.1>, 'sepal width (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=3.5>, 'petal length (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=1.4>, 'petal width (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=0.2>} tf.Tensor(0, shape=(), dtype=int64)
# {'sepal length (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=4.9>, 'sepal width (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=3.0>, 'petal length (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=1.4>, 'petal width (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=0.2>} tf.Tensor(0, shape=(), dtype=int64)
# {'sepal length (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=4.7>, 'sepal width (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=3.2>, 'petal length (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=1.3>, 'petal width (cm)': <tf.Tensor: shape=(), dtype=float32, numpy=0.2>} tf.Tensor(0, shape=(), dtype=int64)

# %%
# !apt-get install subversion
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libapr1 libaprutil1 libserf-1-1 libsvn1
# Suggested packages:
#   db5.3-util libapache2-mod-svn subversion-tools
# The following NEW packages will be installed:
#   libapr1 libaprutil1 libserf-1-1 libsvn1 subversion
# 0 upgraded, 5 newly installed, 0 to remove and 15 not upgraded.
# Need to get 2,237 kB of archives.
# After this operation, 9,910 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libapr1 amd64 1.6.3-2 [90.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaprutil1 amd64 1.6.1-2 [84.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libserf-1-1 amd64 1.3.9-6 [44.4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsvn1 amd64 1.9.7-4ubuntu1 [1,183 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 subversion amd64 1.9.7-4ubuntu1 [834 kB]
# Fetched 2,237 kB in 1s (2,171 kB/s)
# Selecting previously unselected package libapr1:amd64.
# (Reading database ... 145480 files and directories currently installed.)
# Preparing to unpack .../libapr1_1.6.3-2_amd64.deb ...
# Unpacking libapr1:amd64 (1.6.3-2) ...
# Selecting previously unselected package libaprutil1:amd64.
# Preparing to unpack .../libaprutil1_1.6.1-2_amd64.deb ...
# Unpacking libaprutil1:amd64 (1.6.1-2) ...
# Selecting previously unselected package libserf-1-1:amd64.
# Preparing to unpack .../libserf-1-1_1.3.9-6_amd64.deb ...
# Unpacking libserf-1-1:amd64 (1.3.9-6) ...
# Selecting previously unselected package libsvn1:amd64.
# Preparing to unpack .../libsvn1_1.9.7-4ubuntu1_amd64.deb ...
# Unpacking libsvn1:amd64 (1.9.7-4ubuntu1) ...
# Selecting previously unselected package subversion.
# Preparing to unpack .../subversion_1.9.7-4ubuntu1_amd64.deb ...
# Unpacking subversion (1.9.7-4ubuntu1) ...
# Setting up libapr1:amd64 (1.6.3-2) ...
# Setting up libaprutil1:amd64 (1.6.1-2) ...
# Setting up libserf-1-1:amd64 (1.3.9-6) ...
# Setting up libsvn1:amd64 (1.9.7-4ubuntu1) ...
# Setting up subversion (1.9.7-4ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !svnserve --version
# Out:
# svnserve, version 1.9.7 (r1800392)
#    compiled Mar 28 2018, 08:49:13 on x86_64-pc-linux-gnu
#
# Copyright (C) 2017 The Apache Software Foundation.
# This software consists of contributions made by many people;
# see the NOTICE file for more information.
# Subversion is open source software, see http://subversion.apache.org/
#
# The following repository back-end (FS) modules are available:
#
# * fs_fs : Module for working with a plain file (FSFS) repository.
# * fs_x : Module for working with an experimental (FSX) repository.
# * fs_base : Module for working with a Berkeley DB repository.
#
# Cyrus SASL authentication is available.

# %%
# !svn checkout https://github.com/lyhue1991/eat_tensorflow2_in_30_days/trunk/data/cifar2
# Out:
# Streaming output truncated to the last 5000 lines.
# A    cifar2/train/automobile/1.jpg
# A    cifar2/train/automobile/10.jpg
# A    cifar2/train/automobile/100.jpg
# A    cifar2/train/automobile/1000.jpg
# A    cifar2/train/automobile/1001.jpg
# A    cifar2/train/automobile/1002.jpg
# A    cifar2/train/automobile/1003.jpg
# A    cifar2/train/automobile/1004.jpg
# A    cifar2/train/automobile/1005.jpg
# A    cifar2/train/automobile/1006.jpg
# A    cifar2/train/automobile/1007.jpg
# A    cifar2/train/automobile/1008.jpg
# A    cifar2/train/automobile/1009.jpg
# A    cifar2/train/automobile/101.jpg
# A    cifar2/train/automobile/1010.jpg
# A    cifar2/train/automobile/1011.jpg
# A    cifar2/train/automobile/1012.jpg
# A    cifar2/train/automobile/1013.jpg
# A    cifar2/train/automobile/1014.jpg
# A    cifar2/train/automobile/1015.jpg
# A    cifar2/train/automobile/1016.jpg
# A    cifar2/train/automobile/1017.jpg
# A    cifar2/train/automobile/1018.jpg
# A    cifar2/train/automobile/1019.jpg
# A    cifar2/train/automobile/200.jpg
# A    cifar2/train/automobile/2000.jpg
# A    cifar2/train/automobile/2001.jpg
# A    cifar2/train/automobile/2002.jpg
# A    cifar2/train/automobile/2003.jpg
# A    cifar2/train/automobile/2004.jpg
# A    cifar2/train/automobile/2005.jpg
# A    cifar2/train/automobile/2006.jpg
# A    cifar2/train/automobile/2007.jpg
# A    cifar2/train/automobile/2008.jpg
# A    cifar2/train/automobile/2009.jpg
# A    cifar2/train/automobile/201.jpg
# A    cifar2/train/automobile/2010.jpg
# A    cifar2/train/automobile/2011.jpg
# A    cifar2/train/automobile/2012.jpg
# A    cifar2/train/automobile/2013.jpg
# A    cifar2/train/automobile/2014.jpg
# A    cifar2/train/automobile/2015.jpg
# A    cifar2/train/automobile/2016.jpg
# A    cifar2/train/automobile/2017.jpg
# A    cifar2/train/automobile/2018.jpg
# A    cifar2/train/automobile/2019.jpg
# A    cifar2/train/automobile/202.jpg
# A    cifar2/train/automobile/2020.jpg
# A    cifar2/train/automobile/2021.jpg
# A    cifar2/train/automobile/2022.jpg
# A    cifar2/train/automobile/2023.jpg
# A    cifar2/train/automobile/2024.jpg
# A    cifar2/train/automobile/2025.jpg
# A    cifar2/train/automobile/2026.jpg
# A    cifar2/train/automobile/2027.jpg
# A    cifar2/train/automobile/2028.jpg
# A    cifar2/train/automobile/2029.jpg
# A    cifar2/train/automobile/203.jpg
# A    cifar2/train/automobile/2030.jpg
# A    cifar2/train/automobile/2031.jpg
# A    cifar2/train/automobile/2032.jpg
# A    cifar2/train/automobile/2033.jpg
# A    cifar2/train/automobile/2034.jpg
# A    cifar2/train/automobile/2035.jpg
# A    cifar2/train/automobile/2036.jpg
# A    cifar2/train/automobile/2037.jpg
# A    cifar2/train/automobile/2038.jpg
# A    cifar2/train/automobile/2039.jpg
# A    cifar2/train/automobile/204.jpg
# A    cifar2/train/automobile/2040.jpg
# A    cifar2/train/automobile/2041.jpg
# A    cifar2/train/automobile/2042.jpg
# A    cifar2/train/automobile/2043.jpg
# A    cifar2/train/automobile/2044.jpg
# A    cifar2/train/automobile/2045.jpg
# A    cifar2/train/automobile/2046.jpg
# A    cifar2/train/automobile/2047.jpg
# A    cifar2/train/automobile/2048.jpg
# A    cifar2/train/automobile/2049.jpg
# A    cifar2/train/automobile/205.jpg
# A    cifar2/train/automobile/2050.jpg
# A    cifar2/train/automobile/2051.jpg
# A    cifar2/train/automobile/2052.jpg
# A    cifar2/train/automobile/2053.jpg
# A    cifar2/train/automobile/2054.jpg
# A    cifar2/train/automobile/2055.jpg
# A    cifar2/train/automobile/2056.jpg
# A    cifar2/train/automobile/2057.jpg
# A    cifar2/train/automobile/2058.jpg
# A    cifar2/train/automobile/2059.jpg
# A    cifar2/train/automobile/206.jpg
# A    cifar2/train/automobile/2060.jpg
# A    cifar2/train/automobile/2061.jpg
# A    cifar2/train/automobile/2062.jpg
# A    cifar2/train/automobile/2063.jpg
# A    cifar2/train/automobile/2064.jpg
# A    cifar2/train/automobile/2065.jpg
# A    cifar2/train/automobile/2066.jpg
# A    cifar2/train/automobile/2067.jpg
# A    cifar2/train/automobile/2068.jpg
# A    cifar2/train/automobile/2069.jpg
# A    cifar2/train/automobile/207.jpg
# A    cifar2/train/automobile/2070.jpg
# A    cifar2/train/automobile/2071.jpg
# A    cifar2/train/automobile/2072.jpg
# A    cifar2/train/automobile/2073.jpg
# A    cifar2/train/automobile/2074.jpg
# A    cifar2/train/automobile/2075.jpg
# A    cifar2/train/automobile/2076.jpg
# A    cifar2/train/automobile/2077.jpg
# A    cifar2/train/automobile/2078.jpg
# A    cifar2/train/automobile/2079.jpg
# A    cifar2/train/automobile/208.jpg
# A    cifar2/train/automobile/2080.jpg
# A    cifar2/train/automobile/2081.jpg
# A    cifar2/train/automobile/2082.jpg
# A    cifar2/train/automobile/2083.jpg
# A    cifar2/train/automobile/2084.jpg
# A    cifar2/train/automobile/2085.jpg
# A    cifar2/train/automobile/2086.jpg
# A    cifar2/train/automobile/2087.jpg
# A    cifar2/train/automobile/2088.jpg
# A    cifar2/train/automobile/2089.jpg
# A    cifar2/train/automobile/209.jpg
# A    cifar2/train/automobile/2090.jpg
# A    cifar2/train/automobile/2091.jpg
# A    cifar2/train/automobile/2092.jpg
# A    cifar2/train/automobile/2093.jpg
# A    cifar2/train/automobile/2094.jpg
# A    cifar2/train/automobile/2095.jpg
# A    cifar2/train/automobile/2096.jpg
# A    cifar2/train/automobile/2097.jpg
# A    cifar2/train/automobile/2098.jpg
# A    cifar2/train/automobile/2099.jpg
# A    cifar2/train/automobile/21.jpg
# A    cifar2/train/automobile/210.jpg
# A    cifar2/train/automobile/2100.jpg
# A    cifar2/train/automobile/2101.jpg
# A    cifar2/train/automobile/2102.jpg
# A    cifar2/train/automobile/2103.jpg
# A    cifar2/train/automobile/2104.jpg
# A    cifar2/train/automobile/2105.jpg
# A    cifar2/train/automobile/2106.jpg
# A    cifar2/train/automobile/2107.jpg
# A    cifar2/train/automobile/2108.jpg
# A    cifar2/train/automobile/2109.jpg
# A    cifar2/train/automobile/211.jpg
# A    cifar2/train/automobile/2110.jpg
# A    cifar2/train/automobile/2111.jpg
# A    cifar2/train/automobile/2112.jpg
# A    cifar2/train/automobile/2113.jpg
# A    cifar2/train/automobile/2114.jpg
# A    cifar2/train/automobile/2115.jpg
# A    cifar2/train/automobile/2116.jpg
# A    cifar2/train/automobile/2117.jpg
# A    cifar2/train/automobile/2118.jpg
# A    cifar2/train/automobile/2119.jpg
# A    cifar2/train/automobile/212.jpg
# A    cifar2/train/automobile/2120.jpg
# A    cifar2/train/automobile/2121.jpg
# A    cifar2/train/automobile/2122.jpg
# A    cifar2/train/automobile/2123.jpg
# A    cifar2/train/automobile/2124.jpg
# A    cifar2/train/automobile/2125.jpg
# A    cifar2/train/automobile/2126.jpg
# A    cifar2/train/automobile/2127.jpg
# A    cifar2/train/automobile/2128.jpg
# A    cifar2/train/automobile/2129.jpg
# A    cifar2/train/automobile/213.jpg
# A    cifar2/train/automobile/2130.jpg
# A    cifar2/train/automobile/2131.jpg
# A    cifar2/train/automobile/2132.jpg
# A    cifar2/train/automobile/2133.jpg
# A    cifar2/train/automobile/2134.jpg
# A    cifar2/train/automobile/2135.jpg
# A    cifar2/train/automobile/2136.jpg
# ...
# A    cifar2/train/automobile/61.jpg
# A    cifar2/train/automobile/610.jpg
# A    cifar2/train/automobile/611.jpg
# A    cifar2/train/automobile/612.jpg
# A    cifar2/train/automobile/613.jpg
# A    cifar2/train/automobile/614.jpg
# A    cifar2/train/automobile/615.jpg
# A    cifar2/train/automobile/616.jpg
# A    cifar2/train/automobile/617.jpg
# A    cifar2/train/automobile/618.jpg
# A    cifar2/train/automobile/619.jpg
# A    cifar2/train/automobile/62.jpg
# A    cifar2/train/automobile/620.jpg
# A    cifar2/train/automobile/621.jpg
# A    cifar2/train/automobile/622.jpg
# A    cifar2/train/automobile/623.jpg
# A    cifar2/train/automobile/624.jpg
# A    cifar2/train/automobile/625.jpg
# A    cifar2/train/automobile/626.jpg
# A    cifar2/train/automobile/627.jpg
# A    cifar2/train/automobile/628.jpg
# A    cifar2/train/automobile/629.jpg
# A    cifar2/train/automobile/63.jpg
# A    cifar2/train/automobile/630.jpg
# A    cifar2/train/automobile/631.jpg
# A    cifar2/train/automobile/632.jpg
# A    cifar2/train/automobile/633.jpg
# A    cifar2/train/automobile/634.jpg
# A    cifar2/train/automobile/635.jpg
# A    cifar2/train/automobile/636.jpg
# A    cifar2/train/automobile/637.jpg
# A    cifar2/train/automobile/638.jpg
# A    cifar2/train/automobile/639.jpg
# A    cifar2/train/automobile/64.jpg
# A    cifar2/train/automobile/640.jpg
# A    cifar2/train/automobile/641.jpg
# A    cifar2/train/automobile/642.jpg
# A    cifar2/train/automobile/643.jpg
# A    cifar2/train/automobile/644.jpg
# A    cifar2/train/automobile/645.jpg
# A    cifar2/train/automobile/646.jpg
# A    cifar2/train/automobile/647.jpg
# A    cifar2/train/automobile/648.jpg
# A    cifar2/train/automobile/649.jpg
# A    cifar2/train/automobile/65.jpg
# A    cifar2/train/automobile/650.jpg
# A    cifar2/train/automobile/651.jpg
# A    cifar2/train/automobile/652.jpg
# A    cifar2/train/automobile/653.jpg
# A    cifar2/train/automobile/654.jpg
# A    cifar2/train/automobile/655.jpg
# A    cifar2/train/automobile/656.jpg
# A    cifar2/train/automobile/657.jpg
# A    cifar2/train/automobile/658.jpg
# A    cifar2/train/automobile/659.jpg
# A    cifar2/train/automobile/66.jpg
# A    cifar2/train/automobile/660.jpg
# A    cifar2/train/automobile/661.jpg
# A    cifar2/train/automobile/662.jpg
# A    cifar2/train/automobile/663.jpg
# A    cifar2/train/automobile/664.jpg
# A    cifar2/train/automobile/665.jpg
# A    cifar2/train/automobile/666.jpg
# A    cifar2/train/automobile/667.jpg
# A    cifar2/train/automobile/668.jpg
# A    cifar2/train/automobile/669.jpg
# A    cifar2/train/automobile/67.jpg
# A    cifar2/train/automobile/670.jpg
# A    cifar2/train/automobile/671.jpg
# A    cifar2/train/automobile/672.jpg
# A    cifar2/train/automobile/673.jpg
# A    cifar2/train/automobile/674.jpg
# A    cifar2/train/automobile/675.jpg
# A    cifar2/train/automobile/676.jpg
# A    cifar2/train/automobile/677.jpg
# A    cifar2/train/automobile/678.jpg
# A    cifar2/train/automobile/679.jpg
# A    cifar2/train/automobile/68.jpg
# A    cifar2/train/automobile/680.jpg
# A    cifar2/train/automobile/681.jpg
# A    cifar2/train/automobile/682.jpg
# A    cifar2/train/automobile/683.jpg
# A    cifar2/train/automobile/684.jpg
# A    cifar2/train/automobile/685.jpg
# A    cifar2/train/automobile/686.jpg
# A    cifar2/train/automobile/687.jpg
# A    cifar2/train/automobile/688.jpg
# A    cifar2/train/automobile/689.jpg
# A    cifar2/train/automobile/69.jpg
# A    cifar2/train/automobile/690.jpg
# A    cifar2/train/automobile/691.jpg
# A    cifar2/train/automobile/692.jpg
# A    cifar2/train/automobile/693.jpg
# A    cifar2/train/automobile/694.jpg
# A    cifar2/train/automobile/695.jpg
# A    cifar2/train/automobile/696.jpg
# A    cifar2/train/automobile/697.jpg
# A    cifar2/train/automobile/698.jpg
# A    cifar2/train/automobile/699.jpg
# A    cifar2/train/automobile/7.jpg
# A    cifar2/train/automobile/70.jpg
# A    cifar2/train/automobile/700.jpg
# A    cifar2/train/automobile/701.jpg
# A    cifar2/train/automobile/702.jpg
# A    cifar2/train/automobile/703.jpg
# A    cifar2/train/automobile/704.jpg
# A    cifar2/train/automobile/705.jpg
# A    cifar2/train/automobile/706.jpg
# A    cifar2/train/automobile/707.jpg
# A    cifar2/train/automobile/708.jpg
# A    cifar2/train/automobile/709.jpg
# A    cifar2/train/automobile/71.jpg
# A    cifar2/train/automobile/710.jpg
# A    cifar2/train/automobile/711.jpg
# A    cifar2/train/automobile/712.jpg
# A    cifar2/train/automobile/713.jpg
# A    cifar2/train/automobile/714.jpg
# A    cifar2/train/automobile/715.jpg
# A    cifar2/train/automobile/716.jpg
# A    cifar2/train/automobile/717.jpg
# A    cifar2/train/automobile/718.jpg
# A    cifar2/train/automobile/719.jpg
# A    cifar2/train/automobile/72.jpg
# A    cifar2/train/automobile/720.jpg
# A    cifar2/train/automobile/721.jpg
# A    cifar2/train/automobile/722.jpg
# A    cifar2/train/automobile/723.jpg
# A    cifar2/train/automobile/724.jpg
# A    cifar2/train/automobile/725.jpg
# A    cifar2/train/automobile/726.jpg
# A    cifar2/train/automobile/727.jpg
# A    cifar2/train/automobile/728.jpg
# A    cifar2/train/automobile/729.jpg
# A    cifar2/train/automobile/73.jpg
# A    cifar2/train/automobile/730.jpg
# A    cifar2/train/automobile/731.jpg
# A    cifar2/train/automobile/732.jpg
# A    cifar2/train/automobile/733.jpg
# A    cifar2/train/automobile/734.jpg
# A    cifar2/train/automobile/735.jpg
# A    cifar2/train/automobile/736.jpg
# A    cifar2/train/automobile/737.jpg
# A    cifar2/train/automobile/738.jpg
# A    cifar2/train/automobile/739.jpg
# A    cifar2/train/automobile/74.jpg
# A    cifar2/train/automobile/740.jpg
# A    cifar2/train/automobile/741.jpg
# A    cifar2/train/automobile/742.jpg
# A    cifar2/train/automobile/743.jpg
# A    cifar2/train/automobile/744.jpg
# A    cifar2/train/automobile/745.jpg
# A    cifar2/train/automobile/746.jpg
# A    cifar2/train/automobile/747.jpg
# A    cifar2/train/automobile/748.jpg
# A    cifar2/train/automobile/749.jpg
# A    cifar2/train/automobile/75.jpg
# A    cifar2/train/automobile/750.jpg
# A    cifar2/train/automobile/751.jpg
# A    cifar2/train/automobile/752.jpg
# A    cifar2/train/automobile/753.jpg
# A    cifar2/train/automobile/754.jpg
# A    cifar2/train/automobile/755.jpg
# A    cifar2/train/automobile/756.jpg
# A    cifar2/train/automobile/757.jpg
# A    cifar2/train/automobile/758.jpg
# A    cifar2/train/automobile/759.jpg
# A    cifar2/train/automobile/76.jpg
# A    cifar2/train/automobile/760.jpg
# A    cifar2/train/automobile/761.jpg
# A    cifar2/train/automobile/762.jpg
# A    cifar2/train/automobile/763.jpg
# A    cifar2/train/automobile/764.jpg
# A    cifar2/train/automobile/765.jpg
# A    cifar2/train/automobile/766.jpg
# A    cifar2/train/automobile/767.jpg
# A    cifar2/train/automobile/768.jpg
# A    cifar2/train/automobile/769.jpg
# A    cifar2/train/automobile/77.jpg
# A    cifar2/train/automobile/770.jpg
# A    cifar2/train/automobile/771.jpg
# A    cifar2/train/automobile/772.jpg
# A    cifar2/train/automobile/773.jpg
# A    cifar2/train/automobile/774.jpg
# A    cifar2/train/automobile/775.jpg
# A    cifar2/train/automobile/776.jpg
# A    cifar2/train/automobile/777.jpg
# A    cifar2/train/automobile/778.jpg
# A    cifar2/train/automobile/779.jpg
# A    cifar2/train/automobile/78.jpg
# A    cifar2/train/automobile/780.jpg
# A    cifar2/train/automobile/781.jpg
# A    cifar2/train/automobile/782.jpg
# A    cifar2/train/automobile/783.jpg
# A    cifar2/train/automobile/784.jpg
# A    cifar2/train/automobile/785.jpg
# A    cifar2/train/automobile/786.jpg
# A    cifar2/train/automobile/787.jpg
# A    cifar2/train/automobile/788.jpg
# A    cifar2/train/automobile/789.jpg
# A    cifar2/train/automobile/79.jpg
# A    cifar2/train/automobile/790.jpg
# A    cifar2/train/automobile/791.jpg
# A    cifar2/train/automobile/792.jpg
# A    cifar2/train/automobile/793.jpg
# A    cifar2/train/automobile/794.jpg
# A    cifar2/train/automobile/795.jpg
# A    cifar2/train/automobile/796.jpg
# A    cifar2/train/automobile/797.jpg
# A    cifar2/train/automobile/798.jpg
# A    cifar2/train/automobile/799.jpg
# A    cifar2/train/automobile/8.jpg
# A    cifar2/train/automobile/80.jpg
# A    cifar2/train/automobile/800.jpg
# A    cifar2/train/automobile/801.jpg
# A    cifar2/train/automobile/802.jpg
# A    cifar2/train/automobile/803.jpg
# A    cifar2/train/automobile/804.jpg
# A    cifar2/train/automobile/805.jpg
# A    cifar2/train/automobile/806.jpg
# A    cifar2/train/automobile/807.jpg
# A    cifar2/train/automobile/808.jpg
# A    cifar2/train/automobile/809.jpg
# A    cifar2/train/automobile/81.jpg
# A    cifar2/train/automobile/810.jpg
# A    cifar2/train/automobile/811.jpg
# A    cifar2/train/automobile/812.jpg
# A    cifar2/train/automobile/813.jpg
# A    cifar2/train/automobile/814.jpg
# A    cifar2/train/automobile/815.jpg
# A    cifar2/train/automobile/816.jpg
# A    cifar2/train/automobile/817.jpg
# A    cifar2/train/automobile/818.jpg
# A    cifar2/train/automobile/819.jpg
# A    cifar2/train/automobile/82.jpg
# A    cifar2/train/automobile/820.jpg
# A    cifar2/train/automobile/821.jpg
# A    cifar2/train/automobile/822.jpg
# A    cifar2/train/automobile/823.jpg
# A    cifar2/train/automobile/824.jpg
# A    cifar2/train/automobile/825.jpg
# A    cifar2/train/automobile/826.jpg
# A    cifar2/train/automobile/827.jpg
# A    cifar2/train/automobile/828.jpg
# A    cifar2/train/automobile/829.jpg
# A    cifar2/train/automobile/83.jpg
# A    cifar2/train/automobile/830.jpg
# A    cifar2/train/automobile/831.jpg
# A    cifar2/train/automobile/832.jpg
# A    cifar2/train/automobile/833.jpg
# A    cifar2/train/automobile/834.jpg
# A    cifar2/train/automobile/835.jpg
# A    cifar2/train/automobile/836.jpg
# A    cifar2/train/automobile/837.jpg
# A    cifar2/train/automobile/838.jpg
# A    cifar2/train/automobile/839.jpg
# A    cifar2/train/automobile/84.jpg
# A    cifar2/train/automobile/840.jpg
# A    cifar2/train/automobile/841.jpg
# A    cifar2/train/automobile/842.jpg
# A    cifar2/train/automobile/843.jpg
# A    cifar2/train/automobile/844.jpg
# A    cifar2/train/automobile/845.jpg
# A    cifar2/train/automobile/846.jpg
# A    cifar2/train/automobile/847.jpg
# A    cifar2/train/automobile/848.jpg
# A    cifar2/train/automobile/849.jpg
# A    cifar2/train/automobile/85.jpg
# A    cifar2/train/automobile/850.jpg
# A    cifar2/train/automobile/851.jpg
# A    cifar2/train/automobile/852.jpg
# A    cifar2/train/automobile/853.jpg
# A    cifar2/train/automobile/854.jpg
# A    cifar2/train/automobile/855.jpg
# A    cifar2/train/automobile/856.jpg
# A    cifar2/train/automobile/857.jpg
# A    cifar2/train/automobile/858.jpg
# A    cifar2/train/automobile/859.jpg
# A    cifar2/train/automobile/86.jpg
# A    cifar2/train/automobile/860.jpg
# A    cifar2/train/automobile/861.jpg
# A    cifar2/train/automobile/862.jpg
# A    cifar2/train/automobile/863.jpg
# A    cifar2/train/automobile/864.jpg
# A    cifar2/train/automobile/865.jpg
# A    cifar2/train/automobile/866.jpg
# A    cifar2/train/automobile/867.jpg
# A    cifar2/train/automobile/868.jpg
# A    cifar2/train/automobile/869.jpg
# A    cifar2/train/automobile/87.jpg
# A    cifar2/train/automobile/870.jpg
# A    cifar2/train/automobile/871.jpg
# A    cifar2/train/automobile/872.jpg
# A    cifar2/train/automobile/873.jpg
# A    cifar2/train/automobile/874.jpg
# A    cifar2/train/automobile/875.jpg
# A    cifar2/train/automobile/876.jpg
# A    cifar2/train/automobile/877.jpg
# A    cifar2/train/automobile/878.jpg
# A    cifar2/train/automobile/879.jpg
# A    cifar2/train/automobile/88.jpg
# A    cifar2/train/automobile/880.jpg
# A    cifar2/train/automobile/881.jpg
# A    cifar2/train/automobile/882.jpg
# A    cifar2/train/automobile/883.jpg
# A    cifar2/train/automobile/884.jpg
# A    cifar2/train/automobile/885.jpg
# A    cifar2/train/automobile/886.jpg
# A    cifar2/train/automobile/887.jpg
# A    cifar2/train/automobile/888.jpg
# A    cifar2/train/automobile/889.jpg
# A    cifar2/train/automobile/89.jpg
# A    cifar2/train/automobile/890.jpg
# A    cifar2/train/automobile/891.jpg
# A    cifar2/train/automobile/892.jpg
# A    cifar2/train/automobile/893.jpg
# A    cifar2/train/automobile/894.jpg
# A    cifar2/train/automobile/895.jpg
# A    cifar2/train/automobile/896.jpg
# A    cifar2/train/automobile/897.jpg
# A    cifar2/train/automobile/898.jpg
# A    cifar2/train/automobile/899.jpg
# A    cifar2/train/automobile/9.jpg
# A    cifar2/train/automobile/90.jpg
# A    cifar2/train/automobile/900.jpg
# A    cifar2/train/automobile/901.jpg
# A    cifar2/train/automobile/902.jpg
# A    cifar2/train/automobile/903.jpg
# A    cifar2/train/automobile/904.jpg
# A    cifar2/train/automobile/905.jpg
# A    cifar2/train/automobile/906.jpg
# A    cifar2/train/automobile/907.jpg
# A    cifar2/train/automobile/908.jpg
# A    cifar2/train/automobile/909.jpg
# A    cifar2/train/automobile/91.jpg
# A    cifar2/train/automobile/910.jpg
# A    cifar2/train/automobile/911.jpg
# A    cifar2/train/automobile/912.jpg
# A    cifar2/train/automobile/913.jpg
# A    cifar2/train/automobile/914.jpg
# A    cifar2/train/automobile/915.jpg
# A    cifar2/train/automobile/916.jpg
# A    cifar2/train/automobile/917.jpg
# A    cifar2/train/automobile/918.jpg
# A    cifar2/train/automobile/919.jpg
# A    cifar2/train/automobile/92.jpg
# A    cifar2/train/automobile/920.jpg
# A    cifar2/train/automobile/921.jpg
# A    cifar2/train/automobile/922.jpg
# A    cifar2/train/automobile/923.jpg
# A    cifar2/train/automobile/924.jpg
# A    cifar2/train/automobile/925.jpg
# A    cifar2/train/automobile/926.jpg
# A    cifar2/train/automobile/927.jpg
# A    cifar2/train/automobile/928.jpg
# A    cifar2/train/automobile/929.jpg
# A    cifar2/train/automobile/93.jpg
# A    cifar2/train/automobile/930.jpg
# A    cifar2/train/automobile/931.jpg
# A    cifar2/train/automobile/932.jpg
# A    cifar2/train/automobile/933.jpg
# A    cifar2/train/automobile/934.jpg
# A    cifar2/train/automobile/935.jpg
# A    cifar2/train/automobile/936.jpg
# A    cifar2/train/automobile/937.jpg
# A    cifar2/train/automobile/938.jpg
# A    cifar2/train/automobile/939.jpg
# A    cifar2/train/automobile/94.jpg
# A    cifar2/train/automobile/940.jpg
# A    cifar2/train/automobile/941.jpg
# A    cifar2/train/automobile/942.jpg
# A    cifar2/train/automobile/943.jpg
# A    cifar2/train/automobile/944.jpg
# A    cifar2/train/automobile/945.jpg
# A    cifar2/train/automobile/946.jpg
# A    cifar2/train/automobile/947.jpg
# A    cifar2/train/automobile/948.jpg
# A    cifar2/train/automobile/949.jpg
# A    cifar2/train/automobile/95.jpg
# A    cifar2/train/automobile/950.jpg
# A    cifar2/train/automobile/951.jpg
# A    cifar2/train/automobile/952.jpg
# A    cifar2/train/automobile/953.jpg
# A    cifar2/train/automobile/954.jpg
# A    cifar2/train/automobile/955.jpg
# A    cifar2/train/automobile/956.jpg
# A    cifar2/train/automobile/957.jpg
# A    cifar2/train/automobile/958.jpg
# A    cifar2/train/automobile/959.jpg
# A    cifar2/train/automobile/96.jpg
# A    cifar2/train/automobile/960.jpg
# A    cifar2/train/automobile/961.jpg
# A    cifar2/train/automobile/962.jpg
# A    cifar2/train/automobile/963.jpg
# A    cifar2/train/automobile/964.jpg
# A    cifar2/train/automobile/965.jpg
# A    cifar2/train/automobile/966.jpg
# A    cifar2/train/automobile/967.jpg
# A    cifar2/train/automobile/968.jpg
# A    cifar2/train/automobile/969.jpg
# A    cifar2/train/automobile/97.jpg
# A    cifar2/train/automobile/970.jpg
# A    cifar2/train/automobile/971.jpg
# A    cifar2/train/automobile/972.jpg
# A    cifar2/train/automobile/973.jpg
# A    cifar2/train/automobile/974.jpg
# A    cifar2/train/automobile/975.jpg
# A    cifar2/train/automobile/976.jpg
# A    cifar2/train/automobile/977.jpg
# A    cifar2/train/automobile/978.jpg
# A    cifar2/train/automobile/979.jpg
# A    cifar2/train/automobile/98.jpg
# A    cifar2/train/automobile/980.jpg
# A    cifar2/train/automobile/981.jpg
# A    cifar2/train/automobile/982.jpg
# A    cifar2/train/automobile/983.jpg
# A    cifar2/train/automobile/984.jpg
# A    cifar2/train/automobile/985.jpg
# A    cifar2/train/automobile/986.jpg
# A    cifar2/train/automobile/987.jpg
# A    cifar2/train/automobile/988.jpg
# A    cifar2/train/automobile/989.jpg
# A    cifar2/train/automobile/99.jpg
# A    cifar2/train/automobile/990.jpg
# A    cifar2/train/automobile/991.jpg
# A    cifar2/train/automobile/992.jpg
# A    cifar2/train/automobile/993.jpg
# A    cifar2/train/automobile/994.jpg
# A    cifar2/train/automobile/995.jpg
# A    cifar2/train/automobile/996.jpg
# A    cifar2/train/automobile/997.jpg
# A    cifar2/train/automobile/998.jpg
# A    cifar2/train/automobile/999.jpg
# Checked out revision 549.

# %%
# 3,从Python generator构建数据管道
# 从Python generator构建数据管道
import tensorflow as tf
from matplotlib import pyplot as plt 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
image_generator = ImageDataGenerator(rescale=1.0/255).flow_from_directory(
   "/content/cifar2/test/",
   target_size=(32, 32), 
   batch_size=20, 
   class_mode='binary'
)
classdict = image_generator.class_indices
print(classdict)
# Out:
# Found 2000 images belonging to 2 classes.
# {'airplane': 0, 'automobile': 1}

# %%
def generator():
    for features,label in image_generator:
        yield (features,label)

ds3 = tf.data.Dataset.from_generator(generator,output_types=(tf.float32,tf.int32))

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.figure(figsize=(6,6))
for i, (img,label) in enumerate(ds3.unbatch().take(9)):
  ax =plt.subplot(3,3,i+1)
  ax.imshow(img.numpy())
  ax.set_title("label= %d" %label)
  ax.set_xticks([])
  ax.set_yticks([])

plt.show()

# %%
# !svn checkout https://github.com/lyhue1991/eat_tensorflow2_in_30_days/trunk/data/titanic
# Out:
# A    titanic/test.csv
# A    titanic/train.csv
# Checked out revision 549.

# %%
#4,从csv文件构建数据管道
ds4 =tf.data.experimental.make_csv_dataset(
    file_pattern = ["/content/titanic/train.csv","/content/titanic/test.csv"],
    batch_size =3,
    label_name="Survived",
    na_value="",
    num_epochs = 1,
    ignore_errors = True
)

for data,label in ds4.take(2):
  print(data,label)
# Out:
# OrderedDict([('PassengerId', <tf.Tensor: shape=(3,), dtype=int32, numpy=array([ 68, 236, 500], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(3,), dtype=int32, numpy=array([3, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(3,), dtype=string, numpy=
# array([b'Crease, Mr. Ernest James', b'Harknett, Miss. Alice Phoebe',
#        b'Svensson, Mr. Olof'], dtype=object)>), ('Sex', <tf.Tensor: shape=(3,), dtype=string, numpy=array([b'male', b'female', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(3,), dtype=float32, numpy=array([19.,  0., 24.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(3,), dtype=int32, numpy=array([0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(3,), dtype=int32, numpy=array([0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(3,), dtype=string, numpy=array([b'S.P. 3464', b'W./C. 6609', b'350035'], dtype=object)>), ('Fare', <tf.Tensor: shape=(3,), dtype=float32, numpy=array([8.1583, 7.55  , 7.7958], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(3,), dtype=string, numpy=array([b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(3,), dtype=string, numpy=array([b'S', b'S', b'S'], dtype=object)>)]) tf.Tensor([0 0 0], shape=(3,), dtype=int32)
# OrderedDict([('PassengerId', <tf.Tensor: shape=(3,), dtype=int32, numpy=array([ 62, 321, 178], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(3,), dtype=int32, numpy=array([1, 3, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(3,), dtype=string, numpy=
# array([b'Icard, Miss. Amelie', b'Dennis, Mr. Samuel',
#        b'Isham, Miss. Ann Elizabeth'], dtype=object)>), ('Sex', <tf.Tensor: shape=(3,), dtype=string, numpy=array([b'female', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(3,), dtype=float32, numpy=array([38., 22., 50.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(3,), dtype=int32, numpy=array([0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(3,), dtype=int32, numpy=array([0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(3,), dtype=string, numpy=array([b'113572', b'A/5 21172', b'PC 17595'], dtype=object)>), ('Fare', <tf.Tensor: shape=(3,), dtype=float32, numpy=array([80.    ,  7.25  , 28.7125], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(3,), dtype=string, numpy=array([b'B28', b'', b'C49'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(3,), dtype=string, numpy=array([b'', b'S', b'C'], dtype=object)>)]) tf.Tensor([1 0 0], shape=(3,), dtype=int32)

# %%
# 5,从文本文件构建数据管道
# 从文本文件构建数据管道
ds5 = tf.data.TextLineDataset(
    filenames = ["/content/titanic/train.csv","/content/titanic/test.csv"]
    ).skip(1) #略去第一行header

for line in ds5.take(5):
    print(line)
# Out:
# tf.Tensor(b'493,0,1,"Molson, Mr. Harry Markland",male,55.0,0,0,113787,30.5,C30,S', shape=(), dtype=string)
# tf.Tensor(b'53,1,1,"Harper, Mrs. Henry Sleeper (Myna Haxtun)",female,49.0,1,0,PC 17572,76.7292,D33,C', shape=(), dtype=string)
# tf.Tensor(b'388,1,2,"Buss, Miss. Kate",female,36.0,0,0,27849,13.0,,S', shape=(), dtype=string)
# tf.Tensor(b'192,0,2,"Carbines, Mr. William",male,19.0,0,0,28424,13.0,,S', shape=(), dtype=string)
# tf.Tensor(b'687,0,3,"Panula, Mr. Jaako Arnold",male,14.0,4,1,3101295,39.6875,,S', shape=(), dtype=string)

# %%
# 6,从文件路径构建数据管道
ds6 = tf.data.Dataset.list_files("/content/cifar2/train/*/*.jpg")
for file in ds6.take(5):
    print(file)
# Out:
# tf.Tensor(b'/content/cifar2/train/airplane/2401.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/cifar2/train/automobile/4354.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/cifar2/train/airplane/1979.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/cifar2/train/automobile/135.jpg', shape=(), dtype=string)
# tf.Tensor(b'/content/cifar2/train/airplane/601.jpg', shape=(), dtype=string)

# %%
from matplotlib import pyplot as plt

def load_image(img_path,size = (32,32)):
    label = 1 if tf.strings.regex_full_match(img_path,".*/automobile/.*") else 0
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img) #注意此处为jpeg格式
    img = tf.image.resize(img,size)
    return(img,label)

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' # 可缩放矢量图（Scalable Vector Graphics）
for i,(img,label) in enumerate(ds6.map(load_image).take(2)):
    plt.figure(i)
    plt.imshow((img/255.0).numpy())
    plt.title("label = %d"%label)
    plt.xticks([])
    plt.yticks([])

# %%
#7,从tfrecords文件构建数据管道
import os
import numpy as np
# inpath：原始数据路径 outpath:TFRecord文件输出路径
def create_tfrecords(inpath,outpath): 
    writer = tf.io.TFRecordWriter(outpath)
    dirs = os.listdir(inpath)
    for index, name in enumerate(dirs):
        class_path = inpath +"/"+ name+"/"
        for img_name in os.listdir(class_path):
            img_path = class_path + img_name
            img = tf.io.read_file(img_path)
            #img = tf.image.decode_image(img)
            #img = tf.image.encode_jpeg(img) #统一成jpeg格式压缩
            example = tf.train.Example(
               features=tf.train.Features(feature={
                    'label': tf.train.Feature(int64_list=tf.train.Int64List(value=[index])),
                    'img_raw': tf.train.Feature(bytes_list=tf.train.BytesList(value=[img.numpy()]))
               }))
            writer.write(example.SerializeToString())
    writer.close()
    
create_tfrecords("/content/cifar2/test/","/content/cifar2_test.tfrecords/")

# %%
from matplotlib import pyplot as plt 

def parse_example(proto):
    description ={ 'img_raw' : tf.io.FixedLenFeature([], tf.string),
                   'label': tf.io.FixedLenFeature([], tf.int64)} 
    example = tf.io.parse_single_example(proto, description)
    img = tf.image.decode_jpeg(example["img_raw"])   #注意此处为jpeg格式
    img = tf.image.resize(img, (32,32))
    label = example["label"]
    return(img,label)

ds7 = tf.data.TFRecordDataset("/content/cifar2_test.tfrecords/").map(parse_example).shuffle(3000)

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.figure(figsize=(6,6)) 
for i,(img,label) in enumerate(ds7.take(9)):
    ax=plt.subplot(3,3,i+1)
    ax.imshow((img/255.0).numpy())
    ax.set_title("label = %d"%label)
    ax.set_xticks([])
    ax.set_yticks([]) 
plt.show()

# %% [markdown]
# ## 二，应用数据转换
# Dataset数据结构应用非常灵活，因为它本质上是一个Sequece序列，其每个元素可以是各种类型，例如可以是张量，列表，字典，也可以Dataset。
#
# Dataset包含了非常丰富的数据转换功能。
#
# map: 将转换函数映射到数据集每一个元素。
#
# flat_map: 将转换函数映射到数据集的每一个元素，并将嵌套的Dataset压平。
#
# interleave: 效果类似flat_map,但可以将不同来源的数据夹在一起。
#
# filter: 过滤掉某些元素。
#
# zip: 将两个长度相同的Dataset横向铰合。
#
# concatenate: 将两个Dataset纵向连接。
#
# reduce: 执行归并操作。
#
# batch : 构建批次，每次放一个批次。比原始数据增加一个维度。 其逆操作为unbatch。
#
# padded_batch: 构建批次，类似batch, 但可以填充到相同的形状。
#
# window :构建滑动窗口，返回Dataset of Dataset.
#
# shuffle: 数据顺序洗牌。
#
# repeat: 重复数据若干次，不带参数时，重复无数次。
#
# shard: 采样，从某个位置开始隔固定距离采样一个元素。
#
# take: 采样，从开始位置取前几个元素。

# %%
#map:将转换函数映射到数据集每一个元素
ds = tf.data.Dataset.from_tensor_slices(["hello world","hello China","hello Beijing"])
ds_map = ds.map(lambda x:tf.strings.split(x," "))
for x in ds_map:
  print(x)
# Out:
# tf.Tensor([b'hello' b'world'], shape=(2,), dtype=string)
# tf.Tensor([b'hello' b'China'], shape=(2,), dtype=string)
# tf.Tensor([b'hello' b'Beijing'], shape=(2,), dtype=string)

# %%
#flat_map:将转换函数映射到数据集的每一个元素，并将嵌套的Dataset压平。
ds = tf.data.Dataset.from_tensor_slices(["hello world","hello China","hello Beijing"])
for x in ds:
    print(x)
    
ds_map = ds.map(lambda x:tf.strings.split(x," "))
for x in ds_map:
  print(x)

ds_flatmap = ds.flat_map(lambda x:tf.data.Dataset.from_tensor_slices(tf.strings.split(x," ")))
for x in ds_flatmap:
    print(x)
# Out:
# tf.Tensor(b'hello world', shape=(), dtype=string)
# tf.Tensor(b'hello China', shape=(), dtype=string)
# tf.Tensor(b'hello Beijing', shape=(), dtype=string)
# tf.Tensor([b'hello' b'world'], shape=(2,), dtype=string)
# tf.Tensor([b'hello' b'China'], shape=(2,), dtype=string)
# tf.Tensor([b'hello' b'Beijing'], shape=(2,), dtype=string)
# tf.Tensor(b'hello', shape=(), dtype=string)
# tf.Tensor(b'world', shape=(), dtype=string)
# tf.Tensor(b'hello', shape=(), dtype=string)
# tf.Tensor(b'China', shape=(), dtype=string)
# tf.Tensor(b'hello', shape=(), dtype=string)
# tf.Tensor(b'Beijing', shape=(), dtype=string)

# %%
# interleave: 效果类似flat_map,但可以将不同来源的数据夹在一起。

ds = tf.data.Dataset.from_tensor_slices(["hello world","hello China","hello Beijing"])
ds_interleave = ds.interleave(lambda x:tf.data.Dataset.from_tensor_slices(tf.strings.split(x," ")))
for x in ds_interleave:
    print(x)
# Out:
# tf.Tensor(b'hello', shape=(), dtype=string)
# tf.Tensor(b'hello', shape=(), dtype=string)
# tf.Tensor(b'world', shape=(), dtype=string)
# tf.Tensor(b'China', shape=(), dtype=string)
# tf.Tensor(b'hello', shape=(), dtype=string)
# tf.Tensor(b'Beijing', shape=(), dtype=string)

# %%
#filter:过滤掉某些元素。

ds = tf.data.Dataset.from_tensor_slices(["hello world","hello China","hello Beijing"])
#找出含有字母a或B的元素
ds_filter = ds.filter(lambda x: tf.strings.regex_full_match(x, ".*[a|B].*")) #正则表达式
for x in ds_filter:
    print(x)
# Out:
# tf.Tensor(b'hello China', shape=(), dtype=string)
# tf.Tensor(b'hello Beijing', shape=(), dtype=string)

# %%
#zip:将两个长度相同的Dataset横向铰合。
ds1 = tf.data.Dataset.range(0,3)
ds2 = tf.data.Dataset.range(3,6)
ds3 = tf.data.Dataset.range(6,9)
ds_zip = tf.data.Dataset.zip((ds1,ds2,ds3))
for x,y,z in ds_zip:
  print(x.numpy(),y.numpy(),z.numpy())
# Out:
# 0 3 6
# 1 4 7
# 2 5 8

# %%
#condatenate:将两个Dataset纵向连接。
ds1 = tf.data.Dataset.range(0,3)
ds2 = tf.data.Dataset.range(3,6)
ds_concat = tf.data.Dataset.concatenate(ds1,ds2)
for x in ds_concat:
    print(x)
# Out:
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(1, shape=(), dtype=int64)
# tf.Tensor(2, shape=(), dtype=int64)
# tf.Tensor(3, shape=(), dtype=int64)
# tf.Tensor(4, shape=(), dtype=int64)
# tf.Tensor(5, shape=(), dtype=int64)

# %%
#reduce:执行归并操作。

ds = tf.data.Dataset.from_tensor_slices([1,2,3,4,5.0])
result = ds.reduce(0.0,lambda x,y:tf.add(x,y))
result
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=15.0>

# %%
#batch:构建批次，每次放一个批次。比原始数据增加一个维度。 其逆操作为unbatch。 

ds = tf.data.Dataset.range(12)
ds_batch = ds.batch(4)
for x in ds_batch:
    print(x)
# Out:
# tf.Tensor([0 1 2 3], shape=(4,), dtype=int64)
# tf.Tensor([4 5 6 7], shape=(4,), dtype=int64)
# tf.Tensor([ 8  9 10 11], shape=(4,), dtype=int64)

# %%
#padded_batch:构建批次，类似batch, 但可以填充到相同的形状。
elements = [[1, 2],[3, 4, 5],[6, 7],[8]]
ds = tf.data.Dataset.from_generator(lambda: iter(elements), tf.int32)

ds_padded_batch = ds.padded_batch(2,padded_shapes = [4,])

for x in ds_padded_batch:
    print(x)
# Out:
# tf.Tensor(
# [[1 2 0 0]
#  [3 4 5 0]], shape=(2, 4), dtype=int32)
# tf.Tensor(
# [[6 7 0 0]
#  [8 0 0 0]], shape=(2, 4), dtype=int32)

# %%
#window:构建滑动窗口，返回Dataset of Dataset.

ds = tf.data.Dataset.range(12)
#window返回的是Dataset of Dataset,可以用flat_map压平
ds_window = ds.window(3, shift=1).flat_map(lambda x: x.batch(3,drop_remainder=True)) 
for x in ds_window:
    print(x)
# Out:
# tf.Tensor([0 1 2], shape=(3,), dtype=int64)
# tf.Tensor([1 2 3], shape=(3,), dtype=int64)
# tf.Tensor([2 3 4], shape=(3,), dtype=int64)
# tf.Tensor([3 4 5], shape=(3,), dtype=int64)
# tf.Tensor([4 5 6], shape=(3,), dtype=int64)
# tf.Tensor([5 6 7], shape=(3,), dtype=int64)
# tf.Tensor([6 7 8], shape=(3,), dtype=int64)
# tf.Tensor([7 8 9], shape=(3,), dtype=int64)
# tf.Tensor([ 8  9 10], shape=(3,), dtype=int64)
# tf.Tensor([ 9 10 11], shape=(3,), dtype=int64)

# %%
#shuffle:数据顺序洗牌。

ds = tf.data.Dataset.range(12)
ds_shuffle = ds.shuffle(buffer_size = 5)  ## （https://zhuanlan.zhihu.com/p/42417456）buffer——size
for x in ds_shuffle:
    print(x)
# Out:
# tf.Tensor(1, shape=(), dtype=int64)
# tf.Tensor(2, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(6, shape=(), dtype=int64)
# tf.Tensor(3, shape=(), dtype=int64)
# tf.Tensor(4, shape=(), dtype=int64)
# tf.Tensor(10, shape=(), dtype=int64)
# tf.Tensor(8, shape=(), dtype=int64)
# tf.Tensor(9, shape=(), dtype=int64)
# tf.Tensor(11, shape=(), dtype=int64)
# tf.Tensor(7, shape=(), dtype=int64)
# tf.Tensor(5, shape=(), dtype=int64)

# %%
#repeat:重复数据若干次，不带参数时，重复无数次。

ds = tf.data.Dataset.range(3)
ds_repeat = ds.repeat(3)
for x in ds_repeat:
    print(x)
# Out:
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(1, shape=(), dtype=int64)
# tf.Tensor(2, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(1, shape=(), dtype=int64)
# tf.Tensor(2, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(1, shape=(), dtype=int64)
# tf.Tensor(2, shape=(), dtype=int64)

# %%
#shard:采样，从某个位置开始隔固定距离采样一个元素。

ds = tf.data.Dataset.range(12)
ds_shard = ds.shard(2,index = 1)

for x in ds_shard:
    print(x)
# Out:
# tf.Tensor(1, shape=(), dtype=int64)
# tf.Tensor(3, shape=(), dtype=int64)
# tf.Tensor(5, shape=(), dtype=int64)
# tf.Tensor(7, shape=(), dtype=int64)
# tf.Tensor(9, shape=(), dtype=int64)
# tf.Tensor(11, shape=(), dtype=int64)

# %%
#take:采样，从开始位置取前几个元素。

ds = tf.data.Dataset.range(12)
ds_take = ds.take(3)

list(ds_take.as_numpy_iterator())
# Out:
# [0, 1, 2]

# %% [markdown]
# ## 三，提升管道性能
# 训练深度学习模型常常会非常耗时。
#
# 模型训练的耗时主要来自于两个部分，一部分来自数据准备，另一部分来自参数迭代。
#
# 参数迭代过程的耗时通常依赖于GPU来提升。
#
# 而数据准备过程的耗时则可以通过构建高效的数据管道进行提升。
#
# 以下是一些构建高效数据管道的建议。
#
# 1，使用 prefetch 方法让数据准备和参数迭代两个过程相互并行。
#
# 2，使用 interleave 方法可以让数据读取过程多进程执行,并将不同来源数据夹在一起。
#
# 3，使用 map 时设置num_parallel_calls 让数据转换过程多进程执行。
#
# 4，使用 cache 方法让数据在第一个epoch后缓存到内存中，仅限于数据集不大情形。
#
# 5，使用 map转换时，先batch, 然后采用向量化的转换方法对每个batch进行转换
#
# ## 1，使用 prefetch 方法让数据准备和参数迭代两个过程相互并行。

# %%
import tensorflow as tf

#打印时间分割线
@tf.function
def printbar():
    ts = tf.timestamp()
    today_ts = ts%(24*60*60)

    hour = tf.cast(today_ts//3600+2,tf.int32)%tf.constant(24)
    minite = tf.cast((today_ts%3600)//60,tf.int32)
    second = tf.cast(tf.floor(today_ts%60),tf.int32)
    
    def timeformat(m):
        if tf.strings.length(tf.strings.format("{}",m))==1:
            return(tf.strings.format("0{}",m))
        else:
            return(tf.strings.format("{}",m))
    
    timestring = tf.strings.join([timeformat(hour),timeformat(minite),
                timeformat(second)],separator = ":")
    tf.print("=========="*8,end = "")
    tf.print(timestring)

# %%
import time

# 数据准备和参数迭代两个过程默认情况下是串行的。

# 模拟数据准备
def generator():
    for i in range(10):
        #假设每次准备数据需要2s
        time.sleep(2) 
        yield i 
        
ds = tf.data.Dataset.from_generator(generator,output_types = (tf.int32))

# 模拟参数迭代
def train_step():
    #假设每一步训练需要1s
    time.sleep(1)

# %%
# 训练过程预计耗时 10*2+10*1 = 30s
printbar()
tf.print(tf.constant("start training..."))
for x in ds:
    train_step()  
printbar()
tf.print(tf.constant("end training..."))

# 使用 prefetch 方法让数据准备和参数迭代两个过程相互并行。

# 训练过程预计耗时 max(10*2,10*1) = 20s
printbar()
tf.print(tf.constant("start training with prefetch..."))

# tf.data.experimental.AUTOTUNE 可以让程序自动选择合适的参数
for x in ds.prefetch(buffer_size = tf.data.experimental.AUTOTUNE):
    train_step()  
    
printbar()
tf.print(tf.constant("end training..."))
# Out:
# ================================================================================12:08:52
# start training...
# ================================================================================12:09:22
# end training...
# ================================================================================12:09:22
# start training with prefetch...
# ================================================================================12:09:43
# end training...

# %%
# 2，使用 interleave 方法可以让数据读取过程多进程执行,并将不同来源数据夹在一起。

ds_files = tf.data.Dataset.list_files("/content/titanic/*.csv")
ds = ds_files.flat_map(lambda x:tf.data.TextLineDataset(x).skip(1))
for line in ds.take(4):
    print(line)
# Out:
# tf.Tensor(b'493,0,1,"Molson, Mr. Harry Markland",male,55.0,0,0,113787,30.5,C30,S', shape=(), dtype=string)
# tf.Tensor(b'53,1,1,"Harper, Mrs. Henry Sleeper (Myna Haxtun)",female,49.0,1,0,PC 17572,76.7292,D33,C', shape=(), dtype=string)
# tf.Tensor(b'388,1,2,"Buss, Miss. Kate",female,36.0,0,0,27849,13.0,,S', shape=(), dtype=string)
# tf.Tensor(b'192,0,2,"Carbines, Mr. William",male,19.0,0,0,28424,13.0,,S', shape=(), dtype=string)

# %%
ds_files = tf.data.Dataset.list_files("/content/titanic/*.csv")
ds = ds_files.interleave(lambda x:tf.data.TextLineDataset(x).skip(1))
for line in ds.take(8):
    print(line)
# Out:
# tf.Tensor(b'493,0,1,"Molson, Mr. Harry Markland",male,55.0,0,0,113787,30.5,C30,S', shape=(), dtype=string)
# tf.Tensor(b'181,0,3,"Sage, Miss. Constance Gladys",female,,8,2,CA. 2343,69.55,,S', shape=(), dtype=string)
# tf.Tensor(b'53,1,1,"Harper, Mrs. Henry Sleeper (Myna Haxtun)",female,49.0,1,0,PC 17572,76.7292,D33,C', shape=(), dtype=string)
# tf.Tensor(b'405,0,3,"Oreskovic, Miss. Marija",female,20.0,0,0,315096,8.6625,,S', shape=(), dtype=string)
# tf.Tensor(b'388,1,2,"Buss, Miss. Kate",female,36.0,0,0,27849,13.0,,S', shape=(), dtype=string)
# tf.Tensor(b'635,0,3,"Skoog, Miss. Mabel",female,9.0,3,2,347088,27.9,,S', shape=(), dtype=string)
# tf.Tensor(b'192,0,2,"Carbines, Mr. William",male,19.0,0,0,28424,13.0,,S', shape=(), dtype=string)
# tf.Tensor(b'701,1,1,"Astor, Mrs. John Jacob (Madeleine Talmadge Force)",female,18.0,1,0,PC 17757,227.525,C62 C64,C', shape=(), dtype=string)

# %%
# 3，使用 map 时设置num_parallel_calls 让数据转换过程多进行执行。
ds = tf.data.Dataset.list_files("/content/cifar2/train/*/*.jpg")
def load_image(img_path,size = (32,32)):
    label = 1 if tf.strings.regex_full_match(img_path,".*/automobile/.*") else 0
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img) #注意此处为jpeg格式
    img = tf.image.resize(img,size)
    return(img,label)

# %%
#单进程转换
printbar()
tf.print(tf.constant("start transformation..."))

ds_map = ds.map(load_image)
for _ in ds_map:
    pass

printbar()
tf.print(tf.constant("end transformation..."))
# Out:
# ================================================================================12:15:38
# start transformation...
# ================================================================================12:15:44
# end transformation...

# %%
#多进程转换
printbar()
tf.print(tf.constant("start parallel transformation..."))

ds_map_parallel = ds.map(load_image,num_parallel_calls = tf.data.experimental.AUTOTUNE)
for _ in ds_map_parallel:
    pass

printbar()
tf.print(tf.constant("end parallel transformation..."))
# Out:
# ================================================================================12:16:14
# start parallel transformation...
# ================================================================================12:16:18
# end parallel transformation...

# %%
# 4，使用 cache 方法让数据在第一个epoch后缓存到内存中，仅限于数据集不大情形。
import time

# 模拟数据准备
def generator():
    for i in range(5):
        #假设每次准备数据需要2s
        time.sleep(2) 
        yield i 
ds = tf.data.Dataset.from_generator(generator,output_types = (tf.int32))

# 模拟参数迭代
def train_step():
    #假设每一步训练需要0s
    pass

# 训练过程预计耗时 (5*2+5*0)*3 = 30s
printbar()
tf.print(tf.constant("start training..."))
for epoch in tf.range(3):
    for x in ds:
        train_step()  
    printbar()
    tf.print("epoch =",epoch," ended")
printbar()
tf.print(tf.constant("end training..."))
# Out:
# ================================================================================12:18:07
# start training...
# ================================================================================12:18:17
# epoch = 0  ended
# ================================================================================12:18:27
# epoch = 1  ended
# ================================================================================12:18:37
# epoch = 2  ended
# ================================================================================12:18:37
# end training...

# %%
import time

# 模拟数据准备
def generator():
    for i in range(5):
        #假设每次准备数据需要2s
        time.sleep(2) 
        yield i 

# 使用 cache 方法让数据在第一个epoch后缓存到内存中，仅限于数据集不大情形。
ds = tf.data.Dataset.from_generator(generator,output_types = (tf.int32)).cache()

# 模拟参数迭代
def train_step():
    #假设每一步训练需要0s
    time.sleep(0) 

# 训练过程预计耗时 (5*2+5*0)+(5*0+5*0)*2 = 10s
printbar()
tf.print(tf.constant("start training..."))
for epoch in tf.range(3):
    for x in ds:
        train_step()  
    printbar()
    tf.print("epoch =",epoch," ended")
printbar()
tf.print(tf.constant("end training..."))
# Out:
# ================================================================================12:19:11
# start training...
# ================================================================================12:19:21
# epoch = 0  ended
# ================================================================================12:19:21
# epoch = 1  ended
# ================================================================================12:19:21
# epoch = 2  ended
# ================================================================================12:19:21
# end training...

# %%
# 5，使用 map转换时，先batch, 然后采用向量化的转换方法对每个batch进行转换。

#先map后batch
ds = tf.data.Dataset.range(100000)
ds_map_batch = ds.map(lambda x:x**2).batch(20)

printbar()
tf.print(tf.constant("start scalar transformation..."))
for x in ds_map_batch:
    pass
printbar()
tf.print(tf.constant("end scalar transformation..."))
# Out:
# ================================================================================12:20:27
# start scalar transformation...
# ================================================================================12:20:30
# end scalar transformation...

# %%
#先batch后map
ds = tf.data.Dataset.range(100000)
ds_batch_map = ds.batch(20).map(lambda x:x**2)

printbar()
tf.print(tf.constant("start vector transformation..."))
for x in ds_batch_map:
    pass
printbar()
tf.print(tf.constant("end vector transformation..."))
# Out:
# ================================================================================12:20:53
# start vector transformation...
# ================================================================================12:20:54
# end vector transformation...
