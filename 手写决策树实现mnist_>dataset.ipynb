# %% [markdown]
# <a href="https://colab.research.google.com/github/Allen123321/DEMO-DL/blob/master/%E6%89%8B%E5%86%99%E5%86%B3%E7%AD%96%E6%A0%91%E5%AE%9E%E7%8E%B0mnist_%3Edataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#coding=utf-8
#Author:Dodo
#Date:2018-11-21
#Email:lvtengchao@pku.edu.cn

'''
数据集：Mnist
训练集数量：60000
测试集数量：10000
------------------------------
运行结果：ID3(未剪枝)
    正确率：85.9%
    运行时长：356s
'''

import time
import numpy as np

def loadData(fileName):
    '''
    加载文件
    :param fileName:要加载的文件路径
    :return: 数据集和标签集
    '''
    #存放数据及标记
    dataArr = []; labelArr = []
    #读取文件
    fr = open(fileName)
    #遍历文件中的每一行
    for line in fr.readlines():
        #获取当前行，并按“，”切割成字段放入列表中
        #strip：去掉每行字符串首尾指定的字符（默认空格或换行符）
        #split：按照指定的字符将字符串切割成每个字段，返回列表形式
        curLine = line.strip().split(',')
        #将每行中除标记外的数据放入数据集中（curLine[0]为标记信息）
        #在放入的同时将原先字符串形式的数据转换为整型
        #此外将数据进行了二值化处理，大于128的转换成1，小于的转换成0，方便后续计算
        dataArr.append([int(int(num) > 128) for num in curLine[1:]])
        #将标记信息放入标记集中
        #放入的同时将标记转换为整型
        labelArr.append(int(curLine[0]))
    #返回数据集和标记
    return dataArr, labelArr

def majorClass(labelArr):
    '''
    找到当前标签集中占数目最大的标签
    :param labelArr: 标签集
    :return: 最大的标签
    '''
    #建立字典，用于不同类别的标签技术
    classDict = {}
    #遍历所有标签
    for i in range(len(labelArr)):
        #当第一次遇到A标签时，字典内还没有A标签，这时候直接幅值加1是错误的，
        #所以需要判断字典中是否有该键，没有则创建，有就直接自增
        if labelArr[i] in classDict.keys():
            # 若在字典中存在该标签，则直接加1
            classDict[labelArr[i]] += 1
        else:
            #若无该标签，设初值为1，表示出现了1次了
            classDict[labelArr[i]] = 1
    #对字典依据值进行降序排序
    classSort = sorted(classDict.items(), key=lambda x: x[1], reverse=True)
    #返回最大一项的标签，即占数目最多的标签
    return classSort[0][0]

def calc_H_D(trainLabelArr):
    '''
    计算数据集D的经验熵，参考公式5.7 经验熵的计算
    :param trainLabelArr:当前数据集的标签集
    :return: 经验熵
    '''
    #初始化为0
    H_D = 0
    #将当前所有标签放入集合中，这样只要有的标签都会在集合中出现，且出现一次。
    #遍历该集合就可以遍历所有出现过的标记并计算其Ck
    #这么做有一个很重要的原因：首先假设一个背景，当前标签集中有一些标记已经没有了，比如说标签集中
    #没有0（这是很正常的，说明当前分支不存在这个标签）。 式5.7中有一项Ck，那按照式中的针对不同标签k
    #计算Cl和D并求和时，由于没有0，那么C0=0，此时C0/D0=0,log2(C0/D0) = log2(0)，事实上0并不在log的
    #定义区间内，出现了问题
    #所以使用集合的方式先知道当前标签中都出现了那些标签，随后对每个标签进行计算，如果没出现的标签那一项就
    #不在经验熵中出现（未参与，对经验熵无影响），保证log的计算能一直有定义
    trainLabelSet = set([label for label in trainLabelArr])
    #遍历每一个出现过的标签
    for i in trainLabelSet:
        #计算|Ck|/|D|
        #trainLabelArr == i：当前标签集中为该标签的的位置
        #例如a = [1, 0, 0, 1], c = (a == 1): c == [True, false, false, True]
        #trainLabelArr[trainLabelArr == i]：获得为指定标签的样本
        #trainLabelArr[trainLabelArr == i].size：获得为指定标签的样本的大小，即标签为i的样本
        #数量，就是|Ck|
        #trainLabelArr.size：整个标签集的数量（也就是样本集的数量），即|D|
        p = trainLabelArr[trainLabelArr == i].size / trainLabelArr.size
        #对经验熵的每一项累加求和
        H_D += -1 * p * np.log2(p)

    #返回经验熵
    return H_D

def calcH_D_A(trainDataArr_DevFeature, trainLabelArr):
    '''
    计算经验条件熵
    :param trainDataArr_DevFeature:切割后只有feature那列数据的数组
    :param trainLabelArr: 标签集数组
    :return: 经验条件熵
    '''
    #初始为0
    H_D_A = 0
    #在featue那列放入集合中，是为了根据集合中的数目知道该feature目前可取值数目是多少
    trainDataSet = set([label for label in trainDataArr_DevFeature])

    #对于每一个特征取值遍历计算条件经验熵的每一项
    for i in trainDataSet:
        #计算H(D|A)
        #trainDataArr_DevFeature[trainDataArr_DevFeature == i].size / trainDataArr_DevFeature.size:|Di| / |D|
        #calc_H_D(trainLabelArr[trainDataArr_DevFeature == i]):H(Di)
        H_D_A += trainDataArr_DevFeature[trainDataArr_DevFeature == i].size / trainDataArr_DevFeature.size \
                * calc_H_D(trainLabelArr[trainDataArr_DevFeature == i])
    #返回得出的条件经验熵
    return H_D_A

def calcBestFeature(trainDataList, trainLabelList):
    '''
    计算信息增益最大的特征
    :param trainDataList: 当前数据集
    :param trainLabelList: 当前标签集
    :return: 信息增益最大的特征及最大信息增益值
    '''
    #将数据集和标签集转换为数组形式
    trainDataArr = np.array(trainDataList)
    trainLabelArr = np.array(trainLabelList)

    #获取当前特征数目，也就是数据集的横轴大小
    featureNum = trainDataArr.shape[1]

    #初始化最大信息增益
    maxG_D_A = -1
    #初始化最大信息增益的特征
    maxFeature = -1
    
    #“5.2.2 信息增益”中“算法5.1（信息增益的算法）”第一步：
    #1.计算数据集D的经验熵H(D)
    H_D = calc_H_D(trainLabelArr)
    #对每一个特征进行遍历计算
    for feature in range(featureNum):
        #2.计算条件经验熵H(D|A)
        #由于条件经验熵的计算过程中只涉及到标签以及当前特征，为了提高运算速度（全部样本
        #做成的矩阵运算速度太慢，需要剔除不需要的部分），将数据集矩阵进行切割
        #数据集在初始时刻是一个Arr = 60000*784的矩阵，针对当前要计算的feature，在训练集中切割下
        #Arr[:, feature]这么一条来，因为后续计算中数据集中只用到这个（没明白的跟着算一遍例5.2）
        #trainDataArr[:, feature]:在数据集中切割下这么一条
        #trainDataArr[:, feature].flat：将这么一条转换成竖着的列表
        #np.array(trainDataArr[:, feature].flat)：再转换成一条竖着的矩阵，大小为60000*1（只是初始是
        #这么大，运行过程中是依据当前数据集大小动态变的）
        trainDataArr_DevideByFeature = np.array(trainDataArr[:, feature].flat)
        #3.计算信息增益G(D|A)    G(D|A) = H(D) - H(D | A)
        G_D_A = H_D - calcH_D_A(trainDataArr_DevideByFeature, trainLabelArr)
        #不断更新最大的信息增益以及对应的feature
        if G_D_A > maxG_D_A:
            maxG_D_A = G_D_A
            maxFeature = feature
    return maxFeature, maxG_D_A


def getSubDataArr(trainDataArr, trainLabelArr, A, a):
    '''
    更新数据集和标签集
    :param trainDataArr:要更新的数据集
    :param trainLabelArr: 要更新的标签集
    :param A: 要去除的特征索引
    :param a: 当data[A]== a时，说明该行样本时要保留的
    :return: 新的数据集和标签集
    '''
    #返回的数据集
    retDataArr = []
    #返回的标签集
    retLabelArr = []
    #对当前数据的每一个样本进行遍历
    for i in range(len(trainDataArr)):
        #如果当前样本的特征为指定特征值a
        if trainDataArr[i][A] == a:
            #那么将该样本的第A个特征切割掉，放入返回的数据集中
            retDataArr.append(trainDataArr[i][0:A] + trainDataArr[i][A+1:])
            #将该样本的标签放入返回标签集中
            retLabelArr.append(trainLabelArr[i])
    #返回新的数据集和标签集
    return retDataArr, retLabelArr

def createTree(*dataSet):
    '''
    递归创建决策树
    :param dataSet:(trainDataList， trainLabelList) <<-- 元祖形式
    :return:新的子节点或该叶子节点的值
    '''
    #设置Epsilon，“5.3.1 ID3算法”第4步提到需要将信息增益与阈值Epsilon比较，若小于则
    #直接处理后返回T
    #该值的大小在设置上并未考虑太多，观察到信息增益前期在运行中为0.3左右，所以设置了0.1
    Epsilon = 0.1
    #从参数中获取trainDataList和trainLabelList
    #之所以使用元祖作为参数，是由于后续递归调用时直数据集需要对某个特征进行切割，在函数递归
    #调用上直接将切割函数的返回值放入递归调用中，而函数的返回值形式是元祖的，等看到这个函数
    #的底部就会明白了，这样子的用处就是写程序的时候简洁一点，方便一点
    trainDataList = dataSet[0][0]
    trainLabelList = dataSet[0][1]
    #打印信息：开始一个子节点创建，打印当前特征向量数目及当前剩余样本数目
    print('start a node', len(trainDataList[0]), len(trainLabelList))

    #将标签放入一个字典中，当前样本有多少类，在字典中就会有多少项
    #也相当于去重，多次出现的标签就留一次。举个例子，假如处理结束后字典的长度为1，那说明所有的样本
    #都是同一个标签，那就可以直接返回该标签了，不需要再生成子节点了。
    classDict = {i for i in trainLabelList}
    #如果D中所有实例属于同一类Ck，则置T为单节点数，并将Ck作为该节点的类，返回T
    #即若所有样本的标签一致，也就不需要再分化，返回标记作为该节点的值，返回后这就是一个叶子节点
    if len(classDict) == 1:
        #因为所有样本都是一致的，在标签集中随便拿一个标签返回都行，这里用的第0个（因为你并不知道
        #当前标签集的长度是多少，但运行中所有标签只要有长度都会有第0位。
        return trainLabelList[0]

    #如果A为空集，则置T为单节点数，并将D中实例数最大的类Ck作为该节点的类，返回T
    #即如果已经没有特征可以用来再分化了，就返回占大多数的类别
    if len(trainDataList[0]) == 0:
        #返回当前标签集中占数目最大的标签
        return majorClass(trainLabelList)

    #否则，按式5.10计算A中个特征值的信息增益，选择信息增益最大的特征Ag
    Ag, EpsilonGet = calcBestFeature(trainDataList, trainLabelList)

    #如果Ag的信息增益比小于阈值Epsilon，则置T为单节点树，并将D中实例数最大的类Ck
    #作为该节点的类，返回T
    if EpsilonGet < Epsilon:
        return majorClass(trainLabelList)

    #否则，对Ag的每一可能值ai，依Ag=ai将D分割为若干非空子集Di，将Di中实例数最大的
    # 类作为标记，构建子节点，由节点及其子节点构成树T，返回T
    treeDict = {Ag:{}}
    #特征值为0时，进入0分支
    #getSubDataArr(trainDataList, trainLabelList, Ag, 0)：在当前数据集中切割当前feature，返回新的数据集和标签集
    treeDict[Ag][0] = createTree(getSubDataArr(trainDataList, trainLabelList, Ag, 0))
    treeDict[Ag][1] = createTree(getSubDataArr(trainDataList, trainLabelList, Ag, 1))

    return treeDict

def predict(testDataList, tree):
    '''
    预测标签
    :param testDataList:样本
    :param tree: 决策树
    :return: 预测结果
    '''
    # treeDict = copy.deepcopy(tree)

    #死循环，直到找到一个有效地分类
    while True:
        #因为有时候当前字典只有一个节点
        #例如{73: {0: {74:6}}}看起来节点很多，但是对于字典的最顶层来说，只有73一个key，其余都是value
        #若还是采用for来读取的话不太合适，所以使用下行这种方式读取key和value
        (key, value), = tree.items()
        #如果当前的value是字典，说明还需要遍历下去
        if type(tree[key]).__name__ == 'dict':
            #获取目前所在节点的feature值，需要在样本中删除该feature
            #因为在创建树的过程中，feature的索引值永远是对于当时剩余的feature来设置的
            #所以需要不断地删除已经用掉的特征，保证索引相对位置的一致性
            dataVal = testDataList[key]
            del testDataList[key]
            #将tree更新为其子节点的字典
            tree = value[dataVal]
            #如果当前节点的子节点的值是int，就直接返回该int值
            #例如{403: {0: 7, 1: {297:7}}，dataVal=0
            #此时上一行tree = value[dataVal]，将tree定位到了7，而7不再是一个字典了，
            #这里就可以直接返回7了，如果tree = value[1]，那就是一个新的子节点，需要继续遍历下去
            if type(tree).__name__ == 'int':
                #返回该节点值，也就是分类值
                return tree
        else:
            #如果当前value不是字典，那就返回分类值
            return value

def model_test(testDataList, testLabelList, tree):
    '''
    测试准确率
    :param testDataList:待测试数据集
    :param testLabelList: 待测试标签集
    :param tree: 训练集生成的树
    :return: 准确率
    '''
    #错误次数计数
    errorCnt = 0
    #遍历测试集中每一个测试样本
    for i in range(len(testDataList)):
        #判断预测与标签中结果是否一致
        if testLabelList[i] != predict(testDataList[i], tree):
            errorCnt += 1
    #返回准确率
    return 1 - errorCnt / len(testDataList)

if __name__ == '__main__':
    #开始时间
    start = time.time()

    # 获取训练集
    trainDataList, trainLabelList = loadData('/content/sample_data/mnist_train_small.csv')
    # 获取测试集
    testDataList, testLabelList = loadData('/content/sample_data/mnist_test.csv')

    #创建决策树
    print('start create tree')
    tree = createTree((trainDataList, trainLabelList))
    print('tree is:', tree)

    #测试准确率
    print('start test')
    accur = model_test(testDataList, testLabelList, tree)
    print('the accur is:', accur)

    #结束时间
    end = time.time()
    print('time span:', end - start)
# Out:
# start create tree
# start a node 784 20000
# start a node 783 11175
# start a node 782 7971
# start a node 781 6230
# start a node 780 3779
# start a node 779 3334
# start a node 778 2621
# start a node 777 2212
# start a node 776 2039
# start a node 775 1956
# start a node 775 83
# start a node 774 26
# start a node 773 20
# start a node 772 15
# start a node 771 13
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 5
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 773 6
# start a node 772 1
# start a node 772 5
# start a node 774 57
# start a node 773 32
# start a node 772 20
# start a node 771 14
# start a node 770 9
# start a node 770 5
# start a node 769 4
# start a node 769 1
# start a node 771 6
# start a node 772 12
# start a node 771 11
# start a node 771 1
# start a node 773 25
# start a node 772 21
# start a node 772 4
# start a node 771 2
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 776 173
# start a node 775 118
# start a node 774 71
# start a node 773 47
# start a node 772 38
# start a node 771 27
# start a node 770 25
# start a node 769 24
# start a node 768 23
# start a node 768 1
# start a node 769 1
# start a node 770 2
# start a node 771 11
# start a node 770 5
# start a node 770 6
# start a node 769 3
# start a node 768 1
# start a node 768 2
# start a node 767 1
# start a node 767 1
# start a node 769 3
# start a node 772 9
# start a node 771 6
# start a node 770 5
# start a node 770 1
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 773 24
# start a node 772 18
# start a node 771 15
# start a node 770 8
# start a node 769 6
# start a node 768 1
# start a node 768 5
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 770 7
# start a node 769 5
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 771 3
# start a node 772 6
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 3
# start a node 774 47
# start a node 773 25
# start a node 772 19
# start a node 771 14
# start a node 771 5
# start a node 770 4
# start a node 770 1
# start a node 772 6
# start a node 771 5
# start a node 771 1
# start a node 773 22
# start a node 772 21
# start a node 772 1
# start a node 775 55
# start a node 774 47
# start a node 773 43
# start a node 772 42
# start a node 771 41
# start a node 771 1
# start a node 772 1
# start a node 773 4
# start a node 772 2
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 774 8
# start a node 777 409
# start a node 776 213
# start a node 775 173
# start a node 774 141
# start a node 773 96
# start a node 772 63
# start a node 771 61
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 33
# start a node 771 19
# start a node 770 16
# start a node 769 11
# start a node 769 5
# start a node 768 3
# start a node 768 2
# start a node 770 3
# start a node 769 2
# start a node 769 1
# start a node 771 14
# start a node 770 13
# start a node 770 1
# start a node 773 45
# start a node 772 33
# start a node 771 6
# start a node 770 3
# start a node 770 3
# start a node 771 27
# start a node 770 25
# start a node 769 24
# start a node 769 1
# start a node 770 2
# start a node 772 12
# start a node 771 8
# start a node 770 6
# start a node 769 5
# start a node 769 1
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 771 4
# start a node 774 32
# start a node 773 20
# start a node 772 14
# start a node 771 12
# start a node 771 2
# start a node 772 6
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 3
# start a node 773 12
# start a node 772 4
# start a node 771 2
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 8
# start a node 771 2
# start a node 771 6
# start a node 775 40
# start a node 774 23
# start a node 773 19
# start a node 772 15
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 13
# start a node 772 4
# start a node 771 3
# start a node 771 1
# start a node 773 4
# start a node 774 17
# start a node 773 14
# start a node 773 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 1
# start a node 776 196
# start a node 775 110
# start a node 774 48
# start a node 773 34
# start a node 772 29
# start a node 772 5
# start a node 771 2
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 773 14
# start a node 772 4
# start a node 772 10
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 7
# start a node 774 62
# start a node 773 49
# start a node 772 43
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 771 40
# start a node 772 6
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 773 13
# start a node 772 8
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 6
# start a node 770 1
# start a node 770 5
# start a node 772 5
# start a node 775 86
# start a node 774 33
# start a node 773 20
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 772 17
# start a node 771 16
# start a node 770 11
# start a node 770 5
# start a node 769 3
# start a node 769 2
# start a node 771 1
# start a node 773 13
# start a node 772 7
# start a node 771 5
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 6
# start a node 774 53
# start a node 773 51
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 778 713
# start a node 777 625
# start a node 776 337
# start a node 775 257
# start a node 774 224
# start a node 773 182
# start a node 772 177
# start a node 772 5
# start a node 771 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 773 42
# start a node 772 23
# start a node 771 18
# start a node 770 16
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 771 5
# start a node 772 19
# start a node 774 33
# start a node 773 26
# start a node 772 20
# start a node 771 17
# start a node 770 16
# start a node 770 1
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 772 6
# start a node 773 7
# start a node 772 4
# start a node 772 3
# start a node 775 80
# start a node 774 43
# start a node 773 16
# start a node 772 9
# start a node 771 6
# start a node 770 5
# start a node 770 1
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 772 7
# start a node 771 4
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 773 27
# start a node 772 24
# start a node 771 23
# start a node 771 1
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 774 37
# start a node 773 20
# start a node 772 10
# start a node 772 10
# start a node 771 6
# start a node 771 4
# start a node 770 3
# start a node 770 1
# start a node 773 17
# start a node 772 15
# start a node 771 14
# start a node 771 1
# start a node 772 2
# start a node 776 288
# start a node 775 116
# start a node 774 78
# start a node 773 41
# start a node 772 22
# start a node 771 18
# start a node 770 16
# start a node 769 14
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 770 2
# start a node 771 4
# start a node 772 19
# start a node 771 12
# start a node 770 3
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 769 1
# start a node 770 9
# start a node 769 8
# start a node 769 1
# start a node 771 7
# start a node 770 6
# start a node 770 1
# start a node 773 37
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 35
# start a node 774 38
# start a node 773 35
# start a node 772 34
# start a node 772 1
# start a node 773 3
# start a node 775 172
# start a node 774 45
# start a node 773 13
# start a node 772 8
# start a node 771 7
# start a node 771 1
# start a node 772 5
# start a node 771 3
# start a node 771 2
# start a node 773 32
# start a node 772 16
# start a node 771 8
# start a node 770 6
# start a node 770 2
# start a node 771 8
# start a node 772 16
# start a node 771 14
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 774 127
# start a node 773 122
# start a node 772 118
# start a node 772 4
# start a node 773 5
# start a node 772 4
# start a node 772 1
# start a node 777 88
# start a node 776 72
# start a node 775 65
# start a node 774 60
# start a node 773 58
# start a node 772 56
# start a node 772 2
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 774 5
# start a node 773 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 775 7
# start a node 774 4
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 776 16
# start a node 775 7
# start a node 774 6
# start a node 774 1
# start a node 775 9
# start a node 774 6
# start a node 773 5
# start a node 773 1
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 779 445
# start a node 778 247
# start a node 777 195
# start a node 776 175
# start a node 775 83
# start a node 774 58
# start a node 773 29
# start a node 772 11
# start a node 771 6
# start a node 770 5
# start a node 770 1
# start a node 771 5
# start a node 772 18
# start a node 771 12
# start a node 770 9
# start a node 770 3
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 769 1
# start a node 771 6
# start a node 770 2
# start a node 770 4
# start a node 773 29
# start a node 772 25
# start a node 772 4
# start a node 771 3
# start a node 771 1
# start a node 774 25
# start a node 773 20
# start a node 772 10
# start a node 771 8
# start a node 770 7
# start a node 770 1
# start a node 771 2
# start a node 772 10
# start a node 771 7
# start a node 771 3
# start a node 773 5
# start a node 775 92
# start a node 774 78
# start a node 773 65
# start a node 772 25
# start a node 771 13
# start a node 770 9
# start a node 769 8
# start a node 769 1
# start a node 770 4
# start a node 771 12
# start a node 772 40
# start a node 773 13
# start a node 772 6
# start a node 771 4
# start a node 771 2
# start a node 772 7
# start a node 774 14
# start a node 773 13
# start a node 773 1
# start a node 776 20
# start a node 775 18
# start a node 774 1
# start a node 774 17
# start a node 775 2
# start a node 777 52
# start a node 776 16
# start a node 775 7
# start a node 774 4
# start a node 774 3
# start a node 775 9
# start a node 774 8
# start a node 774 1
# start a node 776 36
# start a node 775 35
# start a node 775 1
# start a node 778 198
# start a node 777 177
# start a node 776 165
# start a node 776 12
# start a node 775 5
# start a node 774 2
# start a node 774 3
# start a node 775 7
# start a node 777 21
# start a node 776 15
# start a node 776 6
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 775 4
# start a node 780 2451
# start a node 779 1371
# start a node 778 1145
# start a node 777 943
# start a node 776 855
# start a node 776 88
# start a node 775 57
# start a node 774 40
# start a node 773 27
# start a node 772 19
# start a node 771 17
# start a node 770 11
# start a node 769 6
# start a node 768 2
# start a node 768 4
# start a node 769 5
# start a node 768 2
# start a node 768 3
# start a node 770 6
# start a node 771 2
# start a node 772 8
# start a node 771 4
# start a node 771 4
# start a node 770 3
# start a node 770 1
# start a node 773 13
# start a node 772 8
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 774 17
# start a node 773 8
# start a node 772 6
# start a node 772 2
# start a node 773 9
# start a node 772 5
# start a node 772 4
# start a node 775 31
# start a node 774 28
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 777 202
# start a node 776 143
# start a node 775 30
# start a node 774 9
# start a node 773 7
# start a node 772 6
# start a node 772 1
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 774 21
# start a node 773 14
# start a node 772 13
# start a node 772 1
# start a node 773 7
# start a node 772 4
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 775 113
# start a node 774 109
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 776 59
# start a node 775 54
# start a node 774 52
# start a node 773 51
# start a node 772 50
# start a node 772 1
# start a node 773 1
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 775 5
# start a node 774 4
# start a node 774 1
# start a node 778 226
# start a node 777 104
# start a node 776 90
# start a node 775 77
# start a node 774 69
# start a node 773 67
# start a node 772 66
# start a node 772 1
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 774 8
# start a node 773 6
# start a node 773 2
# start a node 775 13
# start a node 774 7
# start a node 773 6
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 772 3
# start a node 773 1
# start a node 774 6
# start a node 773 1
# start a node 773 5
# start a node 776 14
# start a node 775 8
# start a node 774 7
# start a node 774 1
# start a node 775 6
# start a node 774 5
# start a node 774 1
# start a node 777 122
# start a node 776 70
# start a node 775 52
# start a node 774 36
# start a node 773 27
# start a node 772 9
# start a node 771 7
# start a node 771 2
# start a node 772 18
# start a node 771 14
# start a node 771 4
# start a node 770 2
# start a node 770 2
# start a node 773 9
# start a node 772 8
# start a node 772 1
# start a node 774 16
# start a node 773 15
# start a node 773 1
# start a node 775 18
# start a node 774 15
# start a node 773 13
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 774 3
# start a node 776 52
# start a node 775 47
# start a node 774 26
# start a node 773 17
# start a node 772 16
# start a node 772 1
# start a node 773 9
# start a node 772 5
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 771 2
# start a node 772 4
# start a node 774 21
# start a node 773 14
# start a node 772 13
# start a node 772 1
# start a node 773 7
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 772 2
# start a node 775 5
# start a node 774 2
# start a node 774 3
# start a node 779 1080
# start a node 778 392
# start a node 777 349
# start a node 776 288
# start a node 775 239
# start a node 774 201
# start a node 773 167
# start a node 772 144
# start a node 771 141
# start a node 770 137
# start a node 770 4
# start a node 769 2
# start a node 769 2
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 772 23
# start a node 771 11
# start a node 770 10
# start a node 769 9
# start a node 769 1
# start a node 770 1
# start a node 771 12
# start a node 770 4
# start a node 769 2
# start a node 768 1
# start a node 768 1
# start a node 769 2
# start a node 770 8
# start a node 773 34
# start a node 772 22
# start a node 771 18
# start a node 771 4
# start a node 770 3
# start a node 770 1
# start a node 772 12
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 771 9
# start a node 774 38
# start a node 773 30
# start a node 772 8
# start a node 771 4
# start a node 771 4
# start a node 770 2
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 772 22
# start a node 771 21
# start a node 771 1
# start a node 773 8
# start a node 772 2
# start a node 772 6
# start a node 775 49
# start a node 774 9
# start a node 773 4
# start a node 772 2
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 773 5
# start a node 772 2
# start a node 772 3
# start a node 774 40
# start a node 773 9
# start a node 772 7
# start a node 772 2
# start a node 773 31
# start a node 772 21
# start a node 771 18
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 772 10
# start a node 771 8
# start a node 770 5
# start a node 769 1
# start a node 769 4
# start a node 770 3
# start a node 769 2
# start a node 769 1
# start a node 771 2
# start a node 776 61
# start a node 775 44
# start a node 774 38
# start a node 773 6
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 4
# start a node 771 1
# start a node 771 3
# start a node 773 32
# start a node 774 6
# start a node 773 4
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 775 17
# start a node 774 10
# start a node 773 6
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 774 7
# start a node 773 5
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 777 43
# start a node 776 29
# start a node 776 14
# start a node 775 9
# start a node 774 8
# start a node 774 1
# start a node 775 5
# start a node 774 4
# start a node 774 1
# start a node 778 688
# start a node 777 604
# start a node 776 156
# start a node 775 73
# start a node 774 47
# start a node 773 25
# start a node 772 21
# start a node 771 12
# start a node 770 3
# start a node 770 9
# start a node 769 8
# start a node 769 1
# start a node 771 9
# start a node 770 8
# start a node 770 1
# start a node 772 4
# start a node 773 22
# start a node 772 6
# start a node 771 3
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 772 16
# start a node 771 13
# start a node 770 12
# start a node 770 1
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 774 26
# start a node 773 23
# start a node 773 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 1
# start a node 775 83
# start a node 774 80
# start a node 773 77
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 776 448
# start a node 775 205
# start a node 774 188
# start a node 773 78
# start a node 772 55
# start a node 771 28
# start a node 770 15
# start a node 769 5
# start a node 769 10
# start a node 768 8
# start a node 767 1
# start a node 767 7
# start a node 768 2
# start a node 767 1
# start a node 767 1
# start a node 770 13
# start a node 771 27
# start a node 770 15
# start a node 770 12
# start a node 769 9
# start a node 768 8
# start a node 768 1
# start a node 769 3
# start a node 772 23
# start a node 771 22
# start a node 771 1
# start a node 773 110
# start a node 774 17
# start a node 773 15
# start a node 773 2
# start a node 775 243
# start a node 774 220
# start a node 774 23
# start a node 773 12
# start a node 772 2
# start a node 772 10
# start a node 771 9
# start a node 771 1
# start a node 773 11
# start a node 777 84
# start a node 776 19
# start a node 775 13
# start a node 774 10
# start a node 773 2
# start a node 773 8
# start a node 774 3
# start a node 775 6
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 776 65
# start a node 775 33
# start a node 774 28
# start a node 773 21
# start a node 772 13
# start a node 771 10
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 772 8
# start a node 771 5
# start a node 771 3
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 1
# start a node 773 7
# start a node 774 5
# start a node 773 4
# start a node 773 1
# start a node 775 32
# start a node 774 30
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 781 1741
# start a node 780 1228
# start a node 779 1045
# start a node 778 927
# start a node 777 864
# start a node 776 833
# start a node 775 808
# start a node 775 25
# start a node 774 10
# start a node 773 7
# start a node 773 3
# start a node 774 15
# start a node 773 10
# start a node 772 6
# start a node 771 5
# start a node 771 1
# start a node 772 4
# start a node 773 5
# start a node 776 31
# start a node 775 25
# start a node 774 22
# start a node 773 21
# start a node 773 1
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 775 6
# start a node 774 3
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 777 63
# start a node 776 41
# start a node 775 38
# start a node 774 35
# start a node 773 32
# start a node 772 31
# start a node 772 1
# start a node 773 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 1
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 775 3
# start a node 776 22
# start a node 775 16
# start a node 774 12
# start a node 773 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 1
# start a node 773 9
# start a node 774 4
# start a node 775 6
# start a node 774 5
# start a node 774 1
# start a node 778 118
# start a node 777 86
# start a node 776 70
# start a node 775 61
# start a node 774 56
# start a node 773 54
# start a node 773 2
# start a node 774 5
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 3
# start a node 775 9
# start a node 774 5
# start a node 773 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 1
# start a node 773 2
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 776 16
# start a node 775 5
# start a node 774 2
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 775 11
# start a node 774 9
# start a node 774 2
# start a node 777 32
# start a node 776 22
# start a node 775 16
# start a node 774 14
# start a node 773 13
# start a node 773 1
# start a node 774 2
# start a node 775 6
# start a node 776 10
# start a node 775 7
# start a node 775 3
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 1
# start a node 779 183
# start a node 778 105
# start a node 777 82
# start a node 776 28
# start a node 775 15
# start a node 774 12
# start a node 773 8
# start a node 772 7
# start a node 772 1
# start a node 773 4
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 775 13
# start a node 774 8
# start a node 773 4
# start a node 773 4
# start a node 774 5
# start a node 773 4
# start a node 773 1
# start a node 776 54
# start a node 775 41
# start a node 774 40
# start a node 773 39
# start a node 773 1
# start a node 774 1
# start a node 775 13
# start a node 774 6
# start a node 773 2
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 774 7
# start a node 773 1
# start a node 773 6
# start a node 777 23
# start a node 776 8
# start a node 776 15
# start a node 775 8
# start a node 774 6
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 775 7
# start a node 774 4
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 778 78
# start a node 777 67
# start a node 776 63
# start a node 776 4
# start a node 775 2
# start a node 775 2
# start a node 777 11
# start a node 776 5
# start a node 775 4
# start a node 775 1
# start a node 776 6
# start a node 775 3
# start a node 775 3
# start a node 780 513
# start a node 779 256
# start a node 778 188
# start a node 777 180
# start a node 776 32
# start a node 775 25
# start a node 774 22
# start a node 773 21
# start a node 772 20
# start a node 772 1
# start a node 773 1
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 775 7
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 5
# start a node 776 148
# start a node 775 143
# start a node 775 5
# start a node 774 2
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 777 8
# start a node 776 5
# start a node 776 3
# start a node 775 2
# start a node 775 1
# start a node 778 68
# start a node 777 36
# start a node 776 13
# start a node 775 7
# start a node 774 6
# start a node 774 1
# start a node 775 6
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 774 3
# start a node 776 23
# start a node 775 20
# start a node 774 15
# start a node 774 5
# start a node 773 3
# start a node 773 2
# start a node 775 3
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 1
# start a node 777 32
# start a node 776 9
# start a node 775 7
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 776 23
# start a node 775 5
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 3
# start a node 775 18
# start a node 774 13
# start a node 773 12
# start a node 773 1
# start a node 774 5
# start a node 773 4
# start a node 773 1
# start a node 779 257
# start a node 778 169
# start a node 777 122
# start a node 776 49
# start a node 775 31
# start a node 774 22
# start a node 773 19
# start a node 772 16
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 773 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 1
# start a node 774 9
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 773 5
# start a node 775 18
# start a node 774 8
# start a node 773 7
# start a node 772 6
# start a node 772 1
# start a node 773 1
# start a node 774 10
# start a node 776 73
# start a node 775 63
# start a node 774 21
# start a node 773 12
# start a node 772 9
# start a node 771 1
# start a node 771 8
# start a node 772 3
# start a node 773 9
# start a node 772 4
# start a node 771 1
# start a node 771 3
# start a node 772 5
# start a node 774 42
# start a node 773 40
# start a node 772 39
# start a node 772 1
# start a node 773 2
# start a node 775 10
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 774 7
# start a node 773 6
# start a node 773 1
# start a node 777 47
# start a node 776 5
# start a node 775 3
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 776 42
# start a node 775 38
# start a node 775 4
# start a node 774 2
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 778 88
# start a node 777 73
# start a node 776 11
# start a node 775 6
# start a node 774 4
# start a node 774 2
# start a node 775 5
# start a node 774 2
# start a node 774 3
# start a node 776 62
# start a node 775 60
# start a node 774 55
# start a node 773 54
# start a node 773 1
# start a node 774 5
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 3
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 777 15
# start a node 776 11
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 775 8
# start a node 776 4
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 775 2
# start a node 782 3204
# start a node 781 1941
# start a node 780 922
# start a node 779 678
# start a node 778 522
# start a node 777 445
# start a node 776 201
# start a node 775 123
# start a node 774 89
# start a node 773 62
# start a node 772 50
# start a node 771 37
# start a node 770 26
# start a node 769 22
# start a node 768 8
# start a node 767 4
# start a node 767 4
# start a node 766 2
# start a node 765 1
# start a node 765 1
# start a node 766 2
# start a node 765 1
# start a node 765 1
# start a node 768 14
# start a node 767 12
# start a node 766 11
# start a node 766 1
# start a node 767 2
# start a node 766 1
# start a node 766 1
# start a node 769 4
# start a node 770 11
# start a node 769 9
# start a node 769 2
# start a node 771 13
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 770 11
# start a node 772 12
# start a node 773 27
# start a node 772 18
# start a node 771 15
# start a node 770 14
# start a node 770 1
# start a node 771 3
# start a node 772 9
# start a node 771 8
# start a node 771 1
# start a node 774 34
# start a node 773 33
# start a node 773 1
# start a node 775 78
# start a node 774 26
# start a node 773 18
# start a node 772 14
# start a node 772 4
# start a node 771 3
# start a node 771 1
# start a node 773 8
# start a node 772 7
# start a node 772 1
# start a node 774 52
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 50
# start a node 776 244
# start a node 777 77
# start a node 776 54
# start a node 775 37
# start a node 774 27
# start a node 774 10
# start a node 773 6
# start a node 773 4
# start a node 775 17
# start a node 774 10
# start a node 773 6
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 774 7
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 5
# start a node 776 23
# start a node 775 16
# start a node 774 14
# start a node 774 2
# start a node 775 7
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 778 156
# start a node 777 121
# start a node 776 115
# start a node 775 108
# start a node 774 105
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 775 7
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 776 6
# start a node 775 3
# start a node 774 1
# start a node 774 2
# start a node 775 3
# start a node 777 35
# start a node 776 16
# start a node 775 13
# start a node 774 12
# start a node 774 1
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 776 19
# start a node 775 11
# start a node 774 9
# start a node 773 8
# start a node 773 1
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 775 8
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 774 5
# start a node 779 244
# start a node 778 199
# start a node 777 102
# start a node 776 59
# start a node 775 48
# start a node 774 43
# start a node 773 42
# start a node 772 41
# start a node 772 1
# start a node 773 1
# start a node 774 5
# start a node 773 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 775 11
# start a node 774 6
# start a node 774 5
# start a node 776 43
# start a node 775 24
# start a node 774 20
# start a node 773 19
# start a node 773 1
# start a node 774 4
# start a node 775 19
# start a node 774 18
# start a node 774 1
# start a node 777 97
# start a node 776 84
# start a node 775 79
# start a node 774 28
# start a node 773 23
# start a node 772 19
# start a node 772 4
# start a node 771 3
# start a node 771 1
# start a node 773 5
# start a node 772 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 774 51
# start a node 773 50
# start a node 773 1
# start a node 775 5
# start a node 774 4
# start a node 774 1
# start a node 776 13
# start a node 778 45
# start a node 777 23
# start a node 776 12
# start a node 775 9
# start a node 774 6
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 776 11
# start a node 775 8
# start a node 774 3
# start a node 774 5
# start a node 775 3
# start a node 777 22
# start a node 776 17
# start a node 775 16
# start a node 775 1
# start a node 776 5
# start a node 775 1
# start a node 775 4
# start a node 780 1019
# start a node 779 959
# start a node 779 60
# start a node 778 36
# start a node 777 14
# start a node 776 8
# start a node 775 7
# start a node 775 1
# start a node 776 6
# start a node 775 4
# start a node 774 2
# start a node 774 2
# start a node 775 2
# start a node 777 22
# start a node 776 21
# start a node 776 1
# start a node 778 24
# start a node 777 10
# start a node 776 4
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 775 2
# start a node 776 6
# start a node 777 14
# start a node 781 1263
# start a node 780 833
# start a node 779 708
# start a node 778 677
# start a node 777 657
# start a node 777 20
# start a node 776 9
# start a node 775 7
# start a node 774 6
# start a node 774 1
# start a node 775 2
# start a node 776 11
# start a node 775 9
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 778 31
# start a node 777 16
# start a node 776 13
# start a node 776 3
# start a node 775 2
# start a node 775 1
# start a node 777 15
# start a node 776 4
# start a node 775 3
# start a node 775 1
# start a node 776 11
# start a node 775 10
# start a node 775 1
# start a node 779 125
# start a node 778 77
# start a node 777 28
# start a node 776 21
# start a node 775 18
# start a node 774 17
# start a node 774 1
# start a node 775 3
# start a node 774 1
# start a node 774 2
# start a node 776 7
# start a node 775 4
# start a node 775 3
# start a node 777 49
# start a node 776 12
# start a node 775 10
# start a node 774 1
# start a node 774 9
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 776 37
# start a node 775 14
# start a node 774 10
# start a node 773 7
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 4
# start a node 775 23
# start a node 778 48
# start a node 777 4
# start a node 776 3
# start a node 776 1
# start a node 777 44
# start a node 776 42
# start a node 775 41
# start a node 775 1
# start a node 776 2
# start a node 780 430
# start a node 779 225
# start a node 778 110
# start a node 777 93
# start a node 776 88
# start a node 775 80
# start a node 775 8
# start a node 774 3
# start a node 774 5
# start a node 776 5
# start a node 777 17
# start a node 776 11
# start a node 775 10
# start a node 775 1
# start a node 776 6
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 775 3
# start a node 778 115
# start a node 777 29
# start a node 776 18
# start a node 775 5
# start a node 774 2
# start a node 774 3
# start a node 775 13
# start a node 774 11
# start a node 774 2
# start a node 776 11
# start a node 775 8
# start a node 775 3
# start a node 777 86
# start a node 776 84
# start a node 776 2
# start a node 775 1
# start a node 775 1
# start a node 779 205
# start a node 778 174
# start a node 777 167
# start a node 776 156
# start a node 776 11
# start a node 775 8
# start a node 774 3
# start a node 774 5
# start a node 775 3
# start a node 777 7
# start a node 776 4
# start a node 775 2
# start a node 775 2
# start a node 776 3
# start a node 775 2
# start a node 775 1
# start a node 778 31
# start a node 777 15
# start a node 776 7
# start a node 775 6
# start a node 775 1
# start a node 776 8
# start a node 775 7
# start a node 775 1
# start a node 777 16
# start a node 776 4
# start a node 775 2
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 776 12
# start a node 775 10
# start a node 775 2
# start a node 783 8825
# start a node 782 5068
# start a node 781 3917
# start a node 780 2713
# start a node 779 2212
# start a node 778 1740
# start a node 777 1575
# start a node 776 1483
# start a node 775 462
# start a node 774 353
# start a node 773 160
# start a node 772 76
# start a node 771 34
# start a node 770 15
# start a node 769 12
# start a node 768 6
# start a node 767 3
# start a node 766 2
# start a node 765 1
# start a node 765 1
# start a node 766 1
# start a node 767 3
# start a node 768 6
# start a node 769 3
# start a node 770 19
# start a node 771 42
# start a node 770 15
# start a node 769 12
# start a node 768 4
# start a node 768 8
# start a node 767 7
# start a node 767 1
# start a node 769 3
# start a node 768 2
# start a node 767 1
# start a node 767 1
# start a node 768 1
# start a node 770 27
# start a node 769 23
# start a node 768 19
# start a node 768 4
# start a node 767 3
# start a node 767 1
# start a node 769 4
# start a node 772 84
# start a node 771 80
# start a node 770 64
# start a node 769 63
# start a node 768 62
# start a node 768 1
# start a node 769 1
# start a node 770 16
# start a node 769 12
# start a node 768 2
# start a node 768 10
# start a node 769 4
# start a node 768 2
# start a node 768 2
# start a node 771 4
# start a node 770 1
# start a node 770 3
# start a node 773 193
# start a node 772 190
# start a node 772 3
# start a node 774 109
# start a node 773 57
# start a node 772 37
# start a node 771 17
# start a node 770 12
# start a node 769 4
# start a node 768 3
# start a node 768 1
# start a node 769 8
# start a node 768 7
# start a node 768 1
# start a node 770 5
# start a node 769 4
# start a node 769 1
# start a node 771 20
# start a node 770 19
# start a node 770 1
# start a node 772 20
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 18
# start a node 773 52
# start a node 772 42
# start a node 771 34
# start a node 770 33
# start a node 769 32
# start a node 769 1
# start a node 770 1
# start a node 771 8
# start a node 770 3
# start a node 770 5
# start a node 769 4
# start a node 769 1
# start a node 772 10
# start a node 771 5
# start a node 770 3
# start a node 769 2
# start a node 769 1
# start a node 770 2
# start a node 771 5
# start a node 775 1021
# start a node 774 968
# start a node 774 53
# start a node 773 25
# start a node 772 5
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 3
# start a node 772 20
# start a node 771 18
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 773 28
# start a node 772 23
# start a node 771 13
# start a node 771 10
# start a node 770 8
# start a node 769 1
# start a node 769 7
# start a node 770 2
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 776 92
# start a node 775 59
# start a node 774 37
# start a node 773 31
# start a node 772 29
# start a node 771 27
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 2
# start a node 773 6
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 4
# start a node 774 22
# start a node 773 11
# start a node 772 9
# start a node 772 2
# start a node 773 11
# start a node 772 10
# start a node 772 1
# start a node 775 33
# start a node 774 27
# start a node 773 23
# start a node 772 22
# start a node 772 1
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 774 6
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 3
# start a node 777 165
# start a node 776 111
# start a node 775 54
# start a node 774 13
# start a node 773 10
# start a node 772 8
# start a node 771 5
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 772 2
# start a node 773 3
# start a node 774 41
# start a node 773 37
# start a node 772 35
# start a node 771 34
# start a node 771 1
# start a node 772 2
# start a node 773 4
# start a node 772 2
# start a node 772 2
# start a node 775 57
# start a node 774 19
# start a node 773 7
# start a node 772 5
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 773 12
# start a node 772 8
# start a node 772 4
# start a node 774 38
# start a node 773 37
# start a node 773 1
# start a node 776 54
# start a node 775 38
# start a node 774 30
# start a node 773 28
# start a node 773 2
# start a node 774 8
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 773 4
# start a node 772 2
# start a node 772 2
# start a node 775 16
# start a node 774 12
# start a node 773 6
# start a node 772 4
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 773 6
# start a node 774 4
# start a node 773 1
# start a node 773 3
# start a node 778 472
# start a node 777 407
# start a node 776 169
# start a node 775 103
# start a node 774 74
# start a node 773 39
# start a node 772 18
# start a node 771 8
# start a node 770 6
# start a node 769 5
# start a node 769 1
# start a node 770 2
# start a node 771 10
# start a node 770 8
# start a node 769 5
# start a node 768 4
# start a node 768 1
# start a node 769 3
# start a node 770 2
# start a node 772 21
# start a node 771 16
# start a node 770 14
# start a node 769 13
# start a node 769 1
# start a node 770 2
# start a node 769 1
# start a node 769 1
# start a node 771 5
# start a node 773 35
# start a node 772 34
# start a node 772 1
# start a node 774 29
# start a node 773 14
# start a node 772 11
# start a node 771 10
# start a node 771 1
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 773 15
# start a node 772 13
# start a node 772 2
# start a node 775 66
# start a node 774 31
# start a node 773 4
# start a node 772 1
# start a node 772 3
# start a node 773 27
# start a node 772 23
# start a node 771 16
# start a node 770 13
# start a node 769 11
# start a node 769 2
# start a node 770 3
# start a node 771 7
# start a node 772 4
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 2
# start a node 774 35
# start a node 773 32
# start a node 772 31
# start a node 772 1
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 776 238
# start a node 775 200
# start a node 774 146
# start a node 773 126
# start a node 772 118
# start a node 771 94
# start a node 771 24
# start a node 770 6
# start a node 769 3
# start a node 768 1
# start a node 768 2
# start a node 769 3
# start a node 770 18
# start a node 769 17
# start a node 769 1
# start a node 772 8
# start a node 771 4
# start a node 770 2
# start a node 770 2
# start a node 771 4
# start a node 773 20
# start a node 772 10
# start a node 772 10
# start a node 774 54
# start a node 773 46
# start a node 772 42
# start a node 771 6
# start a node 770 4
# start a node 769 2
# start a node 769 2
# start a node 770 2
# start a node 771 36
# start a node 770 31
# start a node 770 5
# start a node 769 2
# start a node 769 3
# start a node 772 4
# start a node 773 8
# start a node 772 6
# start a node 772 2
# start a node 775 38
# start a node 774 14
# start a node 773 13
# start a node 773 1
# start a node 774 24
# start a node 773 17
# start a node 772 12
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 9
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 773 7
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 772 4
# start a node 771 3
# start a node 771 1
# start a node 777 65
# start a node 776 54
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 775 51
# start a node 776 11
# start a node 775 5
# start a node 774 3
# start a node 774 2
# start a node 775 6
# start a node 774 5
# start a node 774 1
# start a node 779 501
# start a node 778 306
# start a node 777 267
# start a node 776 246
# start a node 775 237
# start a node 774 208
# start a node 774 29
# start a node 773 20
# start a node 772 18
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 773 9
# start a node 772 7
# start a node 771 6
# start a node 771 1
# start a node 772 2
# start a node 775 9
# start a node 774 2
# start a node 774 7
# start a node 773 1
# start a node 773 6
# start a node 776 21
# start a node 775 17
# start a node 774 13
# start a node 773 12
# start a node 773 1
# start a node 774 4
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 2
# start a node 775 4
# start a node 774 2
# start a node 774 2
# start a node 777 39
# start a node 776 27
# start a node 775 21
# start a node 774 13
# start a node 773 9
# start a node 773 4
# start a node 772 2
# start a node 772 2
# start a node 774 8
# start a node 773 2
# start a node 773 6
# start a node 775 6
# start a node 776 12
# start a node 775 6
# start a node 774 3
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 775 6
# start a node 778 195
# start a node 777 87
# start a node 776 53
# start a node 775 28
# start a node 774 20
# start a node 773 16
# start a node 772 11
# start a node 771 3
# start a node 771 8
# start a node 770 7
# start a node 770 1
# start a node 772 5
# start a node 773 4
# start a node 772 3
# start a node 772 1
# start a node 774 8
# start a node 773 6
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 775 25
# start a node 774 22
# start a node 774 3
# start a node 776 34
# start a node 775 19
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 774 15
# start a node 773 14
# start a node 773 1
# start a node 775 15
# start a node 774 8
# start a node 773 4
# start a node 773 4
# start a node 774 7
# start a node 773 2
# start a node 773 5
# start a node 777 108
# start a node 776 91
# start a node 775 23
# start a node 774 15
# start a node 773 12
# start a node 772 7
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 8
# start a node 773 5
# start a node 773 3
# start a node 775 68
# start a node 774 14
# start a node 773 9
# start a node 772 6
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 773 5
# start a node 772 4
# start a node 772 1
# start a node 774 54
# start a node 773 53
# start a node 773 1
# start a node 776 17
# start a node 775 7
# start a node 775 10
# start a node 774 9
# start a node 774 1
# start a node 780 1204
# start a node 779 620
# start a node 778 511
# start a node 777 313
# start a node 776 250
# start a node 775 229
# start a node 774 182
# start a node 773 171
# start a node 772 81
# start a node 771 74
# start a node 770 56
# start a node 769 55
# start a node 769 1
# start a node 770 18
# start a node 769 8
# start a node 768 1
# start a node 768 7
# start a node 769 10
# start a node 771 7
# start a node 770 6
# start a node 770 1
# start a node 772 90
# start a node 771 21
# start a node 770 14
# start a node 769 11
# start a node 769 3
# start a node 770 7
# start a node 769 4
# start a node 768 2
# start a node 768 2
# start a node 769 3
# start a node 771 69
# start a node 770 68
# start a node 770 1
# start a node 773 11
# start a node 772 6
# start a node 771 5
# start a node 771 1
# start a node 772 5
# start a node 771 2
# start a node 771 3
# start a node 774 47
# start a node 773 23
# start a node 772 16
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 13
# start a node 772 7
# start a node 771 6
# start a node 771 1
# start a node 773 24
# start a node 772 18
# start a node 771 12
# start a node 771 6
# start a node 770 3
# start a node 770 3
# start a node 772 6
# start a node 775 21
# start a node 774 16
# start a node 773 11
# start a node 773 5
# start a node 772 3
# start a node 772 2
# start a node 774 5
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 773 2
# start a node 776 63
# start a node 775 37
# start a node 774 17
# start a node 773 9
# start a node 772 8
# start a node 772 1
# start a node 773 8
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 772 3
# start a node 771 1
# start a node 771 2
# start a node 774 20
# start a node 773 11
# start a node 772 10
# start a node 771 8
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 1
# start a node 773 9
# start a node 772 6
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 775 26
# start a node 774 22
# start a node 773 5
# start a node 772 2
# start a node 772 3
# start a node 773 17
# start a node 774 4
# start a node 777 198
# start a node 776 190
# start a node 776 8
# start a node 775 4
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 2
# start a node 775 4
# start a node 778 109
# start a node 777 57
# start a node 776 9
# start a node 775 5
# start a node 774 4
# start a node 774 1
# start a node 775 4
# start a node 774 1
# start a node 774 3
# start a node 776 48
# start a node 775 43
# start a node 774 41
# start a node 774 2
# start a node 775 5
# start a node 774 4
# start a node 774 1
# start a node 777 52
# start a node 776 45
# start a node 775 42
# start a node 774 41
# start a node 774 1
# start a node 775 3
# start a node 776 7
# start a node 775 5
# start a node 774 3
# start a node 774 2
# start a node 775 2
# start a node 779 584
# start a node 778 224
# start a node 777 186
# start a node 776 146
# start a node 775 123
# start a node 774 117
# start a node 773 112
# start a node 773 5
# start a node 774 6
# start a node 775 23
# start a node 774 17
# start a node 773 14
# start a node 772 13
# start a node 772 1
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 6
# start a node 773 3
# start a node 773 3
# start a node 772 1
# start a node 772 2
# start a node 776 40
# start a node 775 35
# start a node 774 32
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 29
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 775 5
# start a node 774 3
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 777 38
# start a node 776 11
# start a node 775 7
# start a node 775 4
# start a node 774 2
# start a node 774 2
# start a node 776 27
# start a node 775 13
# start a node 774 1
# start a node 774 12
# start a node 775 14
# start a node 774 12
# start a node 774 2
# start a node 778 360
# start a node 777 309
# start a node 776 289
# start a node 776 20
# start a node 775 8
# start a node 774 3
# start a node 774 5
# start a node 775 12
# start a node 774 8
# start a node 773 7
# start a node 773 1
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 777 51
# start a node 776 27
# start a node 775 24
# start a node 774 5
# start a node 773 3
# start a node 773 2
# start a node 774 19
# start a node 775 3
# start a node 774 1
# start a node 774 2
# start a node 776 24
# start a node 775 15
# start a node 774 10
# start a node 773 9
# start a node 772 6
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 773 1
# start a node 774 5
# start a node 775 9
# start a node 774 8
# start a node 774 1
# start a node 781 1151
# start a node 780 680
# start a node 779 250
# start a node 778 168
# start a node 777 85
# start a node 776 55
# start a node 775 45
# start a node 774 25
# start a node 773 9
# start a node 772 6
# start a node 771 3
# start a node 770 2
# start a node 770 1
# start a node 771 3
# start a node 772 3
# start a node 773 16
# start a node 772 12
# start a node 771 8
# start a node 770 5
# start a node 770 3
# start a node 771 4
# start a node 772 4
# start a node 774 20
# start a node 773 19
# start a node 772 18
# start a node 772 1
# start a node 773 1
# start a node 775 10
# start a node 774 7
# start a node 773 4
# start a node 773 3
# start a node 774 3
# start a node 776 30
# start a node 775 25
# start a node 775 5
# start a node 774 2
# start a node 774 3
# start a node 777 83
# start a node 776 47
# start a node 775 10
# start a node 774 5
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 3
# start a node 774 5
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 2
# start a node 775 37
# start a node 774 34
# start a node 773 33
# start a node 772 32
# start a node 772 1
# start a node 773 1
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 776 36
# start a node 775 3
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 1
# start a node 775 33
# start a node 774 32
# start a node 773 31
# start a node 773 1
# start a node 774 1
# start a node 778 82
# start a node 777 49
# start a node 776 29
# start a node 775 26
# start a node 774 18
# start a node 773 10
# start a node 773 8
# start a node 772 3
# start a node 772 5
# start a node 771 4
# start a node 771 1
# start a node 774 8
# start a node 773 5
# start a node 773 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 1
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 776 20
# start a node 775 19
# start a node 775 1
# ...
# start a node 777 85
# start a node 776 66
# start a node 775 64
# start a node 774 63
# start a node 774 1
# start a node 775 2
# start a node 776 19
# start a node 775 6
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 774 3
# start a node 775 13
# start a node 774 9
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 780 471
# start a node 779 119
# start a node 778 53
# start a node 777 43
# start a node 776 23
# start a node 775 20
# start a node 775 3
# start a node 774 1
# start a node 774 2
# start a node 776 20
# start a node 775 9
# start a node 774 8
# start a node 774 1
# start a node 775 11
# start a node 774 10
# start a node 774 1
# start a node 777 10
# start a node 776 2
# start a node 776 8
# start a node 778 66
# start a node 777 48
# start a node 776 47
# start a node 775 46
# start a node 775 1
# start a node 776 1
# start a node 777 18
# start a node 776 9
# start a node 775 1
# start a node 775 8
# start a node 776 9
# start a node 775 5
# start a node 774 1
# start a node 774 4
# start a node 775 4
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 2
# start a node 779 352
# start a node 778 258
# start a node 777 208
# start a node 777 50
# start a node 776 6
# start a node 775 1
# start a node 775 5
# start a node 776 44
# start a node 775 26
# start a node 774 23
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 775 18
# start a node 774 8
# start a node 773 5
# start a node 773 3
# start a node 774 10
# start a node 773 4
# start a node 772 1
# start a node 772 3
# start a node 773 6
# start a node 772 1
# start a node 772 5
# start a node 778 94
# start a node 777 42
# start a node 776 25
# start a node 775 2
# start a node 775 23
# start a node 774 1
# start a node 774 22
# start a node 776 17
# start a node 775 15
# start a node 775 2
# start a node 777 52
# start a node 776 10
# start a node 775 6
# start a node 774 5
# start a node 774 1
# start a node 775 4
# start a node 776 42
# start a node 775 40
# start a node 775 2
# start a node 782 3757
# start a node 781 2921
# start a node 780 2522
# start a node 779 2195
# start a node 778 2079
# start a node 777 1818
# start a node 777 261
# start a node 776 82
# start a node 775 73
# start a node 774 6
# start a node 773 4
# start a node 773 2
# start a node 774 67
# start a node 773 14
# start a node 772 6
# start a node 771 5
# start a node 771 1
# start a node 772 8
# start a node 773 53
# start a node 772 52
# start a node 772 1
# start a node 775 9
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 774 6
# start a node 773 5
# start a node 773 1
# start a node 776 179
# start a node 775 150
# start a node 774 14
# start a node 773 9
# start a node 772 6
# start a node 771 4
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 772 3
# start a node 773 5
# start a node 772 4
# start a node 772 1
# start a node 774 136
# start a node 775 29
# start a node 774 10
# start a node 773 5
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 3
# start a node 773 5
# start a node 774 19
# start a node 773 2
# start a node 773 17
# start a node 772 16
# start a node 771 1
# start a node 771 15
# start a node 772 1
# start a node 778 116
# start a node 777 51
# start a node 776 19
# start a node 775 9
# start a node 774 1
# start a node 774 8
# start a node 775 10
# start a node 774 6
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 776 32
# start a node 775 24
# start a node 774 20
# start a node 773 17
# start a node 772 16
# start a node 772 1
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 4
# start a node 775 8
# start a node 774 6
# start a node 773 4
# start a node 773 2
# start a node 774 2
# start a node 777 65
# start a node 776 55
# start a node 775 44
# start a node 774 18
# start a node 773 10
# start a node 773 8
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 772 5
# start a node 774 26
# start a node 773 25
# start a node 773 1
# start a node 775 11
# start a node 774 8
# start a node 774 3
# start a node 776 10
# start a node 775 5
# start a node 774 4
# start a node 774 1
# start a node 775 5
# start a node 779 327
# start a node 778 142
# start a node 777 78
# start a node 776 56
# start a node 775 35
# start a node 774 13
# start a node 773 7
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 5
# start a node 773 6
# start a node 772 4
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 774 22
# start a node 773 13
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 772 10
# start a node 771 3
# start a node 770 1
# start a node 770 2
# start a node 771 7
# start a node 773 9
# start a node 775 21
# start a node 774 18
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 776 22
# start a node 775 17
# start a node 774 15
# start a node 774 2
# start a node 775 5
# start a node 777 64
# start a node 776 61
# start a node 775 56
# start a node 775 5
# start a node 774 2
# start a node 774 3
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 773 1
# start a node 776 3
# start a node 775 2
# start a node 775 1
# start a node 778 185
# start a node 777 130
# start a node 776 88
# start a node 775 14
# start a node 774 10
# start a node 773 4
# start a node 772 2
# start a node 772 2
# start a node 773 6
# start a node 772 2
# start a node 772 4
# start a node 774 4
# start a node 773 2
# start a node 773 2
# start a node 775 74
# start a node 774 35
# start a node 773 22
# start a node 772 16
# start a node 771 4
# start a node 770 2
# start a node 770 2
# start a node 771 12
# start a node 770 11
# start a node 770 1
# start a node 772 6
# start a node 773 13
# start a node 772 7
# start a node 771 3
# start a node 771 4
# start a node 772 6
# start a node 771 4
# start a node 770 1
# start a node 770 3
# start a node 771 2
# start a node 774 39
# start a node 773 10
# start a node 772 9
# start a node 772 1
# start a node 773 29
# start a node 772 28
# start a node 772 1
# start a node 776 42
# start a node 775 23
# start a node 774 13
# start a node 773 11
# start a node 772 10
# start a node 772 1
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 774 10
# start a node 773 7
# start a node 772 5
# start a node 772 2
# start a node 773 3
# start a node 772 2
# start a node 771 1
# start a node 771 1
# start a node 772 1
# start a node 775 19
# start a node 774 11
# start a node 774 8
# start a node 773 4
# start a node 772 2
# start a node 772 2
# start a node 773 4
# start a node 777 55
# start a node 776 45
# start a node 775 41
# start a node 774 31
# start a node 774 10
# start a node 773 4
# start a node 773 6
# start a node 772 2
# start a node 772 4
# start a node 775 4
# start a node 774 3
# start a node 774 1
# start a node 776 10
# start a node 775 3
# start a node 775 7
# start a node 780 399
# start a node 779 308
# start a node 778 257
# start a node 777 212
# start a node 776 200
# start a node 775 37
# start a node 774 14
# start a node 773 9
# start a node 772 8
# start a node 772 1
# start a node 773 5
# start a node 772 3
# start a node 771 2
# start a node 770 1
# start a node 770 1
# start a node 771 1
# start a node 772 2
# start a node 774 23
# start a node 773 21
# start a node 773 2
# start a node 772 1
# start a node 772 1
# start a node 775 163
# start a node 776 12
# start a node 775 10
# start a node 774 9
# start a node 774 1
# start a node 775 2
# start a node 777 45
# start a node 776 27
# start a node 775 24
# start a node 774 23
# start a node 774 1
# start a node 775 3
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 1
# start a node 776 18
# start a node 775 11
# start a node 774 7
# start a node 773 4
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 774 4
# start a node 775 7
# start a node 778 51
# start a node 777 17
# start a node 776 11
# start a node 775 3
# start a node 774 1
# start a node 774 2
# start a node 775 8
# start a node 776 6
# start a node 777 34
# start a node 776 27
# start a node 776 7
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 775 4
# start a node 779 91
# start a node 778 30
# start a node 777 24
# start a node 776 2
# start a node 775 1
# start a node 775 1
# start a node 776 22
# start a node 777 6
# start a node 776 3
# start a node 776 3
# start a node 775 1
# start a node 775 2
# start a node 778 61
# start a node 777 37
# start a node 776 1
# start a node 776 36
# start a node 775 30
# start a node 775 6
# start a node 774 2
# start a node 774 4
# start a node 777 24
# start a node 776 16
# start a node 775 1
# start a node 775 15
# start a node 776 8
# start a node 775 5
# start a node 774 4
# start a node 774 1
# start a node 775 3
# start a node 774 2
# start a node 774 1
# start a node 781 836
# start a node 780 449
# start a node 779 228
# start a node 778 103
# start a node 777 80
# start a node 776 34
# start a node 775 25
# start a node 774 17
# start a node 773 15
# start a node 772 12
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 773 2
# start a node 774 8
# start a node 773 5
# start a node 772 2
# start a node 772 3
# start a node 773 3
# start a node 775 9
# start a node 774 8
# start a node 774 1
# start a node 776 46
# start a node 775 40
# start a node 774 35
# start a node 774 5
# start a node 773 3
# start a node 773 2
# start a node 775 6
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 4
# start a node 777 23
# start a node 776 7
# start a node 775 5
# start a node 775 2
# start a node 776 16
# start a node 775 6
# start a node 774 2
# start a node 773 1
# start a node 773 1
# start a node 774 4
# start a node 775 10
# start a node 774 7
# start a node 774 3
# start a node 778 125
# start a node 777 100
# start a node 776 19
# start a node 775 13
# start a node 774 5
# start a node 773 3
# start a node 772 2
# start a node 772 1
# start a node 773 2
# start a node 774 8
# start a node 773 7
# start a node 773 1
# start a node 775 6
# start a node 776 81
# start a node 775 62
# start a node 774 5
# start a node 773 2
# start a node 773 3
# start a node 774 57
# start a node 773 56
# start a node 773 1
# start a node 775 19
# start a node 774 14
# start a node 773 9
# start a node 772 3
# start a node 771 2
# start a node 771 1
# start a node 772 6
# start a node 773 5
# start a node 774 5
# start a node 773 4
# start a node 773 1
# start a node 777 25
# start a node 776 19
# start a node 776 6
# start a node 775 3
# start a node 775 3
# start a node 774 1
# start a node 774 2
# start a node 779 221
# start a node 778 51
# start a node 777 22
# start a node 776 16
# start a node 775 14
# start a node 774 13
# start a node 774 1
# start a node 775 2
# start a node 776 6
# start a node 775 3
# start a node 775 3
# start a node 777 29
# start a node 776 25
# start a node 775 10
# start a node 774 4
# start a node 773 3
# start a node 773 1
# start a node 774 6
# start a node 775 15
# start a node 774 1
# start a node 774 14
# start a node 776 4
# start a node 775 2
# start a node 775 2
# start a node 778 170
# start a node 777 150
# start a node 776 145
# start a node 775 139
# start a node 775 6
# start a node 774 3
# start a node 774 3
# start a node 773 1
# start a node 773 2
# start a node 776 5
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 775 3
# start a node 777 20
# start a node 776 14
# start a node 775 6
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 774 3
# start a node 775 8
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 774 5
# start a node 776 6
# start a node 780 387
# start a node 779 320
# start a node 778 93
# start a node 777 24
# start a node 776 10
# start a node 775 1
# start a node 775 9
# start a node 776 14
# start a node 775 7
# start a node 774 5
# start a node 774 2
# start a node 775 7
# start a node 774 4
# start a node 774 3
# start a node 773 2
# start a node 773 1
# start a node 777 69
# start a node 776 64
# start a node 775 54
# start a node 775 10
# start a node 774 3
# start a node 774 7
# start a node 776 5
# start a node 775 3
# start a node 775 2
# start a node 774 1
# start a node 774 1
# start a node 778 227
# start a node 779 67
# start a node 778 46
# start a node 777 36
# start a node 776 13
# start a node 775 12
# start a node 775 1
# start a node 776 23
# start a node 775 6
# start a node 774 1
# start a node 774 5
# start a node 775 17
# start a node 774 16
# start a node 774 1
# start a node 777 10
# start a node 778 21
# start a node 777 2
# start a node 777 19
# start a node 776 2
# start a node 775 1
# start a node 775 1
# start a node 776 17
# tree is: {378: {0: {567: {0: {541: {0: {429: {0: {619: {0: {485: {0: {403: {0: {154: {0: {455: {0: 7, 1: {452: {0: {426: {0: {400: {0: {188: {0: 7, 1: {156: {0: 4, 1: 3}}}}, 1: {235: {0: {289: {0: 4, 1: 8}}, 1: {181: {0: 3, 1: 9}}}}}}, 1: {208: {0: 5, 1: 9}}}}, 1: {236: {0: {425: {0: {265: {0: {181: {0: 4, 1: {213: {0: 9, 1: 2}}}}, 1: 9}}, 1: {273: {0: 4, 1: 5}}}}, 1: {401: {0: 9, 1: {210: {0: 4, 1: {183: {0: 5, 1: 9}}}}}}}}}}}}, 1: {538: {0: {349: {0: {565: {0: {129: {0: {377: {0: {481: {0: {172: {0: {290: {0: 0, 1: 3}}, 1: 2}}, 1: 9}}, 1: {430: {0: 3, 1: {259: {0: {126: {0: 2, 1: {126: {0: 4, 1: 0}}}}, 1: 9}}}}}}, 1: {594: {0: {156: {0: 5, 1: 8}}, 1: {100: {0: 0, 1: 1}}}}}}, 1: {643: {0: {424: {0: {621: {0: {241: {0: {180: {0: 4, 1: 1}}, 1: {150: {0: 4, 1: 7}}}}, 1: {351: {0: 2, 1: {99: {0: 7, 1: 1}}}}}}, 1: 6}}, 1: {267: {0: {126: {0: 2, 1: 5}}, 1: 3}}}}}}, 1: {266: {0: {267: {0: {290: {0: 5, 1: {127: {0: 3, 1: 5}}}}, 1: {209: {0: 3, 1: 9}}}}, 1: {401: {0: 3, 1: 1}}}}}}, 1: {376: {0: {263: {0: {372: {0: {379: {0: 2, 1: 7}}, 1: 8}}, 1: {126: {0: 7, 1: {73: {0: 5, 1: 6}}}}}}, 1: 8}}}}}}, 1: {380: {0: {379: {0: {406: {0: {349: {0: {180: {0: {507: {0: 5, 1: {101: {0: 2, 1: 6}}}}, 1: {234: {0: {215: {0: {613: {0: 3, 1: {211: {0: 5, 1: 3}}}}, 1: {150: {0: 5, 1: 8}}}}, 1: {229: {0: 5, 1: 8}}}}}}, 1: {509: {0: {322: {0: {151: {0: 5, 1: 3}}, 1: {507: {0: {376: {0: 3, 1: 8}}, 1: 8}}}}, 1: {217: {0: {99: {0: {177: {0: 1, 1: 8}}, 1: {71: {0: 4, 1: 6}}}}, 1: 5}}}}}}, 1: {185: {0: {239: {0: {101: {0: 4, 1: 6}}, 1: {233: {0: {233: {0: 3, 1: 8}}, 1: 9}}}}, 1: {483: {0: {128: {0: 2, 1: {123: {0: 5, 1: 3}}}}, 1: {182: {0: 9, 1: 8}}}}}}}}, 1: {184: {0: {154: {0: {209: {0: {321: {0: {70: {0: 3, 1: 2}}, 1: 4}}, 1: {148: {0: 9, 1: 3}}}}, 1: 8}}, 1: {266: {0: 8, 1: {69: {0: {155: {0: 4, 1: 8}}, 1: 2}}}}}}}}, 1: {484: {0: {210: {0: {237: {0: {155: {0: 4, 1: {183: {0: 5, 1: {152: {0: 9, 1: 3}}}}}}, 1: {352: {0: 4, 1: {397: {0: {185: {0: 7, 1: 8}}, 1: 9}}}}}}, 1: {319: {0: {231: {0: {398: {0: {122: {0: {183: {0: 8, 1: 9}}, 1: 3}}, 1: 9}}, 1: {181: {0: {179: {0: 7, 1: 3}}, 1: {203: {0: 9, 1: 8}}}}}}, 1: {185: {0: {456: {0: {129: {0: 9, 1: 5}}, 1: {430: {0: 9, 1: 4}}}}, 1: 9}}}}}}, 1: {649: {0: {212: {0: {431: {0: {125: {0: 8, 1: 6}}, 1: {219: {0: {210: {0: 4, 1: {266: {0: 4, 1: 8}}}}, 1: 2}}}}, 1: {232: {0: {266: {0: 9, 1: {148: {0: 7, 1: 4}}}}, 1: 8}}}}, 1: {455: {0: 8, 1: {157: {0: 3, 1: 0}}}}}}}}}}}}, 1: {403: {0: {210: {0: {265: {0: {182: {0: {536: {0: {318: {0: 4, 1: {283: {0: 5, 1: {202: {0: 2, 1: 7}}}}}}, 1: {267: {0: {269: {0: {586: {0: 6, 1: {96: {0: 4, 1: 2}}}}, 1: 4}}, 1: 4}}}}, 1: {288: {0: {151: {0: {644: {0: {127: {0: 9, 1: 2}}, 1: {154: {0: 7, 1: 8}}}}, 1: 2}}, 1: {127: {0: 4, 1: 6}}}}}}, 1: {424: {0: {260: {0: {343: {0: {213: {0: {152: {0: 2, 1: 7}}, 1: {187: {0: 7, 1: 8}}}}, 1: {480: {0: 9, 1: {187: {0: 2, 1: 4}}}}}}, 1: {354: {0: {336: {0: 7, 1: 9}}, 1: {270: {0: 0, 1: 9}}}}}}, 1: {380: {0: {378: {0: 5, 1: {214: {0: 4, 1: {159: {0: 9, 1: 4}}}}}}, 1: {204: {0: {131: {0: 9, 1: 4}}, 1: 7}}}}}}}}, 1: {425: {0: {396: {0: {231: {0: {509: {0: {204: {0: {400: {0: {530: {0: 9, 1: {118: {0: 3, 1: 2}}}}, 1: 3}}, 1: 7}}, 1: {672: {0: {535: {0: {98: {0: {127: {0: 3, 1: 5}}, 1: 4}}, 1: {189: {0: 2, 1: 7}}}}, 1: {156: {0: 7, 1: 3}}}}}}, 1: {210: {0: {153: {0: 2, 1: 3}}, 1: 7}}}}, 1: {345: {0: {292: {0: 9, 1: 4}}, 1: 4}}}}, 1: {380: {0: {430: {0: {459: {0: {296: {0: 5, 1: 2}}, 1: {206: {0: 4, 1: 2}}}}, 1: {288: {0: {475: {0: {154: {0: 9, 1: 4}}, 1: 4}}, 1: {179: {0: 9, 1: {153: {0: 8, 1: 6}}}}}}}}, 1: {190: {0: {435: {0: 9, 1: 4}}, 1: {160: {0: 4, 1: 5}}}}}}}}}}, 1: {242: {0: {323: {0: {324: {0: {205: {0: {120: {0: 6, 1: 2}}, 1: {150: {0: 9, 1: 8}}}}, 1: {296: {0: 8, 1: {206: {0: 2, 1: 9}}}}}}, 1: {347: {0: 2, 1: {125: {0: 8, 1: 4}}}}}}, 1: {458: {0: {125: {0: 5, 1: 1}}, 1: {243: {0: {424: {0: 8, 1: 2}}, 1: {148: {0: 3, 1: 4}}}}}}}}}}}}, 1: {480: {0: {483: {0: {358: {0: {322: {0: {327: {0: {372: {0: {457: {0: {583: {0: {164: {0: 3, 1: 5}}, 1: 5}},  ...
# start test
# the accur is: 0.8241
# time span: 171.24532890319824
